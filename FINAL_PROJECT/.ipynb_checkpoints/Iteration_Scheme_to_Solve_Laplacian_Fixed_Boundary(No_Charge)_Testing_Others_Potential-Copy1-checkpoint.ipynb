# %%
import time, os, math
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# %%
def LAPLACIAN_JACOBI(phi_old, source, neighbor_r, neighbor_l, neighbor_u, neighbor_d, idx):
    return 0.25*(phi_old[neighbor_r[idx]]+phi_old[neighbor_l[idx]]+phi_old[neighbor_u[idx]]+phi_old[neighbor_d[idx]]\
                 -dx**2*source[idx])
    
def LAPLACIAN_GAUSS_SEIDEL(phi_old, source, neighbor_r, neighbor_l, neighbor_u, neighbor_d, idx_even, idx_odd):
    phi_old[idx_even] = 0.25*(phi_old[neighbor_r[idx_even]]+phi_old[neighbor_l[idx_even]]\
                              +phi_old[neighbor_u[idx_even]]+phi_old[neighbor_d[idx_even]]-dx**2*source[idx_even])
    phi_old[idx_odd] = 0.25*(phi_old[neighbor_r[idx_odd]]+phi_old[neighbor_l[idx_odd]]\
                             +phi_old[neighbor_u[idx_odd]]+phi_old[neighbor_d[idx_odd]]-dx**2*source[idx_odd])
    return phi_old

def LAPLACIAN_SUCCESSIVE_OVER_RELAXATION(phi_old, omega, source, neighbor_r, neighbor_l, neighbor_u, neighbor_d, idx_even, idx_odd):
    phi_old[idx_even] += 0.25*omega*(phi_old[neighbor_r[idx_even]]+phi_old[neighbor_l[idx_even]]+phi_old[neighbor_u[idx_even]]\
                                     +phi_old[neighbor_d[idx_even]]-dx**2*source[idx_even]-4.*phi_old[idx_even])
    phi_old[idx_odd] += 0.25*omega*(phi_old[neighbor_r[idx_odd]]+phi_old[neighbor_l[idx_odd]]+phi_old[neighbor_u[idx_odd]]\
                                     +phi_old[neighbor_d[idx_odd]]-dx**2*source[idx_odd]-4.*phi_old[idx_odd])
    return phi_old
    
def CALCULATE_CRITERIA(phi, source, neighbor_r, neighbor_l, neighbor_u, neighbor_d):
    diff = (1./dx**2*(phi[neighbor_r]+phi[neighbor_l]+phi[neighbor_u]+phi[neighbor_d]-4.*phi)-source)[boundary==False]
    return (diff**2).mean()

def CHECKER_BOARD(N):
    A = np.arange(N*N//2)
    X = (2*A)%N
    Y = (2*A)//N
    P = (X+Y+1)%2
    X += P
    ODD_INDEX = (X + Y*N).copy()
    ODD_INDEX = ODD_INDEX[((ODD_INDEX//N!=N-1)&(ODD_INDEX//N!=0)&(ODD_INDEX%N!=N-1)&(ODD_INDEX%N!=0))]
    
    X = (2*A)%N
    Y = (2*A)//N
    P = (X+Y)%2
    X += P
    EVEN_INDEX = (X + Y*N).copy()
    EVEN_INDEX = EVEN_INDEX[((EVEN_INDEX//N!=N-1)&(EVEN_INDEX//N!=0)&(EVEN_INDEX%N!=N-1)&(EVEN_INDEX%N!=0))]
    return EVEN_INDEX, ODD_INDEX

# %%
L = 1.0
N = 1024
dx = dx = L/(N-1)
x = np.arange(0,N)
y = np.arange(0,N)
xx,yy= np.meshgrid(x,y)

phi_analytic = np.exp(dx*xx-dx*yy)*dx*xx*(1.-dx*xx)*dx*yy*(1.-dx*yy)
rho = (2*dx*xx*(dx*yy-1.)*(dx*yy-2.*dx*xx+dx*xx*dx*yy+2.)*np.exp(dx*xx-dx*yy)).ravel()
# phi_analytic = (1.0-yy)

phi = np.zeros(N*N)

boundary = ((yy%N==0) | (yy%N==N-1) | (xx%N==0) | (xx%N==N-1)).ravel()
phi[boundary] = phi_analytic.ravel()[boundary]
iteration = 0
iteration_max = 4000000
show_error_interval = 100
# mode = 'jacobi'
# mode = 'gauss_seidel'
mode = 'SOR'

neighbor_r = np.arange(N*N)
neighbor_l = np.arange(N*N)
neighbor_u = np.arange(N*N)
neighbor_d = np.arange(N*N)
neighbor_r = N*(neighbor_r//N) + (neighbor_r%N+1)%N
neighbor_l = N*(neighbor_l//N) + (neighbor_l%N+N-1)%N
neighbor_u = N*((neighbor_u//N+1)%N) + neighbor_u%N
neighbor_d = N*((neighbor_d//N+N-1)%N) + neighbor_d%N

# criteria = CALCULATE_CRITERIA(phi_analytic.ravel(), rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)
criteria = 1e-21
error = CALCULATE_CRITERIA(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)

# %%
phi_analytic = np.exp(dx*xx-dx*yy)*dx*xx*(1.-dx*xx)*dx*yy*(1.-dx*yy)
rho = (2*dx*xx*(dx*yy-1.)*(dx*yy-2.*dx*xx+dx*xx*dx*yy+2.)*np.exp(dx*xx-dx*yy)).ravel()

# %%
(((phi[neighbor_r]+phi[neighbor_l]+phi[neighbor_u]+phi[neighbor_d]-4.*phi)/dx**2-rho)**2).reshape(N,N)
# Out:
# array([[0.00000000e+00, 7.07810415e-02, 2.78941739e-01, 6.11051396e-01,
#         1.04299931e+00, 1.53895035e+00, 2.05105852e+00, 2.52041768e+00,
#         2.87990690e+00, 3.05981976e+00, 2.99746599e+00, 2.65231768e+00,
#         2.02876208e+00, 1.20914600e+00, 4.00584417e-01, 0.00000000e+00],
#        [0.00000000e+00, 5.81512385e-02, 2.31601160e-01, 5.13598754e-01,
#         8.89353912e-01, 1.33490291e+00, 1.81636918e+00, 2.28991962e+00,
#         2.70283368e+00, 2.99625513e+00, 3.11039443e+00, 2.99320444e+00,
#         2.61387880e+00, 1.98293834e+00, 1.18119932e+00, 4.00584417e-01],
#        [0.00000000e+00, 4.71614948e-02, 1.89674229e-01, 4.25358813e-01,
#         7.46180861e-01, 1.13718798e+00, 1.57562200e+00, 2.03038800e+00,
#         2.46213643e+00, 2.82431318e+00, 3.06566053e+00, 3.13481752e+00,
#         2.98788177e+00, 2.60006704e+00, 1.98293834e+00, 1.20914600e+00],
#        [0.00000000e+00, 3.77026829e-02, 1.53011351e-01, 3.46685440e-01,
#         6.15375575e-01, 9.50712673e-01, 1.33844698e+00, 1.75774175e+00,
#         2.18077292e+00, 2.57284781e+00, 2.89333662e+00, 3.09781593e+00,
#         3.14195892e+00, 2.98788177e+00, 2.61387880e+00, 2.02876208e+00],
#        [0.00000000e+00, 2.96543371e-02, 1.21365256e-01, 2.77599936e-01,
#         4.98066508e-01, 7.78983793e-01, 1.11233647e+00, 1.48517233e+00,
#         1.87902636e+00, 2.26959375e+00, 2.62682349e+00, 2.91566895e+00,
#         3.09781593e+00, 3.13481752e+00, 2.99320444e+00, 2.65231768e+00],
#        [0.00000000e+00, 2.28900217e-02, 9.44189870e-02, 2.17864061e-01,
#         3.94749720e-01, 6.24295077e-01, 9.02819407e-01, 1.22313375e+00,
#         1.57396260e+00, 1.93946154e+00, 2.29892584e+00, 2.62682349e+00,
#         2.89333662e+00, 3.06566053e+00, 3.11039443e+00, 2.99746599e+00],
#        [0.00000000e+00, 1.72816294e-02, 7.18094187e-02, 1.67044184e-01,
#         3.05414041e-01, 4.87918850e-01, 7.13687040e-01, 9.79496365e-01,
#         1.27927897e+00, 1.60364328e+00, 1.93946154e+00, 2.26959375e+00,
#         2.57284781e+00, 2.82431318e+00, 2.99625513e+00, 3.05981976e+00],
#        [0.00000000e+00, 1.27027448e-02, 5.31466377e-02, 1.24566487e-01,
#         2.29654027e-01, 3.70291201e-01, 5.47240930e-01, 7.59798473e-01,
#         1.00541096e+00, 1.27927897e+00, 1.57396260e+00, 1.87902636e+00,
#         2.18077292e+00, 2.46213643e+00, 2.70283368e+00, 2.87990690e+00],
#        [0.00000000e+00, 9.03120290e-03, 3.80296119e-02, 8.97635307e-02,
#         1.66769388e-01, 2.71183885e-01, 4.04543157e-01, 5.67548277e-01,
#         7.59798473e-01, 9.79496365e-01, 1.22313375e+00, 1.48517233e+00,
#         1.75774175e+00, 2.03038800e+00, 2.28991962e+00, 2.52041768e+00],
#        [0.00000000e+00, 6.15096393e-03, 2.60585685e-02, 6.19127863e-02,
#         1.15850577e-01, 1.89858996e-01, 2.85655440e-01, 4.04543157e-01,
#         5.47240930e-01, 7.13687040e-01, 9.02819407e-01, 1.11233647e+00,
#         1.33844698e+00, 1.57562200e+00, 1.81636918e+00, 2.05105852e+00],
#        [0.00000000e+00, 3.95341619e-03, 1.68445156e-02, 4.02678498e-02,
#         7.58509478e-02, 1.25204602e-01, 1.89858996e-01, 2.71183885e-01,
#         3.70291201e-01, 4.87918850e-01, 6.24295077e-01, 7.78983793e-01,
#         9.50712673e-01, 1.13718798e+00, 1.33490291e+00, 1.53895035e+00],
#        [0.00000000e+00, 2.33820784e-03, 1.00163188e-02, 2.40831539e-02,
#         4.56463334e-02, 7.58509478e-02, 1.15850577e-01, 1.66769388e-01,
#         2.29654027e-01, 3.05414041e-01, 3.94749720e-01, 4.98066508e-01,
#         6.15375575e-01, 7.46180861e-01, 8.89353912e-01, 1.04299931e+00],
#        [0.00000000e+00, 1.21369631e-03, 5.22571837e-03, 1.26330009e-02,
#         2.40831539e-02, 4.02678498e-02, 6.19127863e-02, 8.97635307e-02,
#         1.24566487e-01, 1.67044184e-01, 2.17864061e-01, 2.77599936e-01,
#         3.46685440e-01, 4.25358813e-01, 5.13598754e-01, 6.11051396e-01],
#        [0.00000000e+00, 4.97093434e-04, 2.15063684e-03, 5.22571837e-03,
#         1.00163188e-02, 1.68445156e-02, 2.60585685e-02, 3.80296119e-02,
#         5.31466377e-02, 7.18094187e-02, 9.44189870e-02, 1.21365256e-01,
#         1.53011351e-01, 1.89674229e-01, 2.31601160e-01, 2.78941739e-01],
#        [0.00000000e+00, 1.14373274e-04, 4.97093434e-04, 1.21369631e-03,
#         2.33820784e-03, 3.95341619e-03, 6.15096393e-03, 9.03120290e-03,
#         1.27027448e-02, 1.72816294e-02, 2.28900217e-02, 2.96543371e-02,
#         3.77026829e-02, 4.71614948e-02, 5.81512385e-02, 7.07810415e-02],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])

# %%
error**0.5
# Out:
# 0.9688489036526429

# %%
L = 1.0
N = 64
dx = dx = L/(N-1)
x = np.arange(0,N)
y = np.arange(0,N)
xx,yy= np.meshgrid(x,y)

phi_analytic = np.exp(dx*xx-dx*yy)*dx*xx*(1.-dx*xx)*dx*yy*(1.-dx*yy)
rho = (2*dx*xx*(dx*yy-1.)*(dx*yy-2.*dx*xx+dx*xx*dx*yy+2.)*np.exp(dx*xx-dx*yy)).ravel()
# phi_analytic = (1.0-yy)

phi = np.zeros(N*N)

boundary = ((yy%N==0) | (yy%N==N-1) | (xx%N==0) | (xx%N==N-1)).ravel()
phi[boundary] = phi_analytic.ravel()[boundary]
iteration = 0
iteration_max = 4000000
show_error_interval = 100
# mode = 'jacobi'
# mode = 'gauss_seidel'
mode = 'SOR'

neighbor_r = np.arange(N*N)
neighbor_l = np.arange(N*N)
neighbor_u = np.arange(N*N)
neighbor_d = np.arange(N*N)
neighbor_r = N*(neighbor_r//N) + (neighbor_r%N+1)%N
neighbor_l = N*(neighbor_l//N) + (neighbor_l%N+N-1)%N
neighbor_u = N*((neighbor_u//N+1)%N) + neighbor_u%N
neighbor_d = N*((neighbor_d//N+N-1)%N) + neighbor_d%N

# criteria = CALCULATE_CRITERIA(phi_analytic.ravel(), rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)
criteria = 1e-21
error = CALCULATE_CRITERIA(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)
print("Lattice size = %d using %s scheme:"%(N, mode))
if mode=='jacobi':
    phi_copy = phi.copy()
    flag = True
    #     idx_boundary = boundary==False
    idx_not_boundary = np.argwhere(boundary==False).reshape(-1)
elif mode=='gauss_seidel' or mode=='SOR':
    idx_even, idx_odd = CHECKER_BOARD(N)
    if mode == 'SOR':
        omega = 1.9
start = time.time()
while error>criteria and iteration<iteration_max:
    if mode=='jacobi':
        if flag:
            phi_copy[boundary==False] = LAPLACIAN_JACOBI(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d, idx_not_boundary)
            error = CALCULATE_CRITERIA(phi_copy, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)
        else:
            phi[boundary==False] = LAPLACIAN_JACOBI(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d, idx_not_boundary)
            error = CALCULATE_CRITERIA(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)
        flag = not flag
    elif mode=='gauss_seidel':
        phi = LAPLACIAN_GAUSS_SEIDEL(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d, idx_even, idx_odd)
        error = CALCULATE_CRITERIA(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)
    else:
        phi = LAPLACIAN_SUCCESSIVE_OVER_RELAXATION(phi, omega, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d, idx_even, idx_odd)
        error = CALCULATE_CRITERIA(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)
    iteration += 1
    if iteration%show_error_interval == 0:
        print("Iteration = %d, error = %.4e , criteria = %.4e ."%(iteration, error, criteria))
if mode=='jacobi':
    if flag:
        phi = phi.copy()
end = time.time()

print("\tSimulation of %s scheme ends. Total %.2f s is spent."%(mode, end-start))
print("\tError %.4e has been reached, total iterations is %d ."%(error, iteration))
print("\tError with analytic solution is %.8e ."%(((phi-phi_analytic.ravel())**2).mean())**0.5)
phi = np.array(phi.reshape(N,N))
# Out:
# Lattice size = 16 using SOR scheme:
# Iteration = 100, error = 6.8085e-09 , criteria = 1.0000e-21 .
# Iteration = 200, error = 1.1525e-17 , criteria = 1.0000e-21 .
# 	Simulation of SOR scheme ends. Total 0.01 s is spent.
# 	Error 3.5315e-22 has been reached, total iterations is 240 .
# 	Error with analytic solution is 7.44677635e-05 .

# %%
fig = plt.figure(figsize=(2*6,6), dpi=300)

ax_1 = fig.add_subplot(1, 2, 1, projection='3d')
surf = ax_1.plot_surface(dx*xx, dx*yy, phi, cmap='jet', edgecolor='none', )
ax_1.set_title('Simulated Potential', fontsize=20, y=1.05)
ax_1.view_init(90,-90)
ax_1.axis('tight')
ax_1.set_xlim([0,L])
ax_1.set_ylim([0,L])
ax_1.set_xticks(np.linspace(0,L,5))
ax_1.set_yticks(np.linspace(0,L,5))
ax_1.set_xticklabels(np.linspace(0,L,5), fontsize=10., va='center')
ax_1.set_yticklabels(np.linspace(0,L,5), fontsize=10., va='center', rotation=90)
ax_1.set_zticks([])
ax_1.set_xlabel('x', labelpad=10, fontsize=16)
ax_1.set_ylabel('y', labelpad=10, fontsize=16)
axins_1 = inset_axes(ax_1,
                    width="5%",  # width = 50% of parent_bbox width
                    height="40%",  # height : 5%
                    loc='upper right',
                    bbox_to_anchor=(0.01, -0.2, 1, 1), #(position_x, position_y, bbox_size_x, bbox_size_y)
                    bbox_transform=ax_1.transAxes)
fig.colorbar(surf, shrink=0.3, aspect=10, cax=axins_1)

ax_2 = fig.add_subplot(1, 2, 2, projection='3d')
surf = ax_2.plot_surface(dx*xx, dx*yy, phi_analytic, cmap='jet', edgecolor='none', )
ax_2.set_title('Analytical Potential', fontsize=20, y=1.05)
ax_2.view_init(90,-90)
ax_2.axis('tight')
ax_2.set_xlim([0,L])
ax_2.set_ylim([0,L])
ax_2.set_xticks(np.linspace(0,L,5))
ax_2.set_yticks(np.linspace(0,L,5))
ax_2.set_xticklabels(np.linspace(0,L,5), fontsize=10., va='center')
ax_2.set_yticklabels(np.linspace(0,L,5), fontsize=10., va='center', rotation=90)
ax_2.set_zticks([])
ax_2.set_xlabel('x', labelpad=10, fontsize=16.)
ax_2.set_ylabel('y', labelpad=10, fontsize=16.)
axins_2 = inset_axes(ax_2,
                    width="5%",  # width = 50% of parent_bbox width
                    height="40%",  # height : 5%
                    loc='upper right',
                    bbox_to_anchor=(0.01, -0.2, 1, 1), #(position_x, position_y, bbox_size_x, bbox_size_y)
                    bbox_transform=ax_2.transAxes)
fig.colorbar(surf, shrink=0.3, aspect=10, cax=axins_2)
# plt.savefig("/home/lab/Guan_Ming/Computational_Astrophysics/Homework/HW3/Problem_1_Simulated_v.s._Analytic_Potential_N=256_criteria=1.00000000e-21.png", bbox_inches='tight', dpi=200, pad_inches=0.05)
plt.show()

# %%
difference = phi-phi_analytic
ticks=np.linspace(difference.min(), difference.max(),5)

fig = plt.figure(figsize=(3,3), dpi=200)
ax = plt.imshow(difference[::-1,:], cmap='jet') #flip the phi to consistent with the figures above
plt.title("Difference with Analytic Potential", y=1.05)
plt.xlabel('x')
plt.ylabel('y')
plt.xticks(np.linspace(0,N,5), np.linspace(0,L,5))
plt.yticks(np.linspace(0,N,5), np.flip(np.linspace(0,L,5))) # flip the y axis

fig.colorbar(ax, shrink=0.5, aspect=10, ticks=ticks, format='%.2e')
# plt.savefig("/home/lab/Guan_Ming/Computational_Astrophysics/Homework/HW3/Problem_1_Simulated_v.s._Analytic_Potential_Difference_N=256_criteria=1.00000000e-21.png", bbox_inches='tight', dpi=200, pad_inches=0.05)
plt.show()

# %% [markdown]
# ### Lattice Size v.s. Error, Iterations, Total Time

# %%
L = 1.0
N_range = np.array([16, 32, 64, 128, 256])
for mode in ['jacobi']:
    error_analytic_record = []
    total_time_record = []
    iteration_record = []
    for N in N_range:
        k = 2.0*np.pi/N
        x = np.arange(0,N)
        y = np.arange(0,N)
        xx,yy= np.meshgrid(x,y)

        phi_analytic = np.exp(-k*xx)*np.sin(k*yy)
        # phi_analytic = (1.0-yy)

        phi = np.zeros(N*N)
        rho = np.zeros(N*N)
        boundary = ((yy%N==0) | (yy%N==N-1) | (xx%N==0) | (xx%N==N-1)).ravel()
        phi[boundary] = phi_analytic.ravel()[boundary]
        iteration = 0
        iteration_max = 4000000
        dx = L/N
        show_error_interval = 100

        neighbor_r = np.arange(N*N)
        neighbor_l = np.arange(N*N)
        neighbor_u = np.arange(N*N)
        neighbor_d = np.arange(N*N)
        neighbor_r = N*(neighbor_r//N) + (neighbor_r%N+1)%N
        neighbor_l = N*(neighbor_l//N) + (neighbor_l%N+N-1)%N
        neighbor_u = N*((neighbor_u//N+1)%N) + neighbor_u%N
        neighbor_d = N*((neighbor_d//N+N-1)%N) + neighbor_d%N

        # criteria = CALCULATE_CRITERIA(phi_analytic.ravel(), rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)
        criteria = 1e-21
        error = CALCULATE_CRITERIA(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)
        print("Lattice size = %d using %s scheme:"%(N, mode))
        if mode=='jacobi':
            phi_copy = phi.copy()
            flag = True
            #     idx_boundary = boundary==False
            idx_not_boundary = np.argwhere(boundary==False).reshape(-1)
        elif mode=='gauss_seidel' or mode=='SOR':
            idx_all = np.argwhere(boundary==False).reshape(-1)
            idx_even = idx_all[idx_all%2==0]
            idx_odd = idx_all[idx_all%2==1]
            if mode == 'SOR':
                omega = 1.33
        start = time.time()
        while error>criteria and iteration<iteration_max:
            if mode=='jacobi':
                if flag:
                    phi_copy[boundary==False] = LAPLACIAN_JACOBI(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d, idx_not_boundary)
                    error = CALCULATE_CRITERIA(phi_copy, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)
                else:
                    phi[boundary==False] = LAPLACIAN_JACOBI(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d, idx_not_boundary)
                    error = CALCULATE_CRITERIA(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)
                flag = not flag
            elif mode=='gauss_seidel':
                phi = LAPLACIAN_GAUSS_SEIDEL(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d, idx_even, idx_odd)
                error = CALCULATE_CRITERIA(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)
            else:
                phi = LAPLACIAN_SUCCESSIVE_OVER_RELAXATION(phi, omega, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d, idx_even, idx_odd)
                error = CALCULATE_CRITERIA(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)
            iteration += 1
    #         if iteration%show_error_interval == 0:
    #             print("Iteration = %d, error = %.4e , criteria = %.4e ."%(iteration, error, criteria))
        if mode=='jacobi':
            if flag:
                phi = phi.copy()
        end = time.time()
        iteration_record.append(iteration)
        error_analytic_record.append((((phi-phi_analytic.ravel())**2).mean())**0.5)
        total_time_record.append(end-start)
        print("\tSimulation of %s scheme ends. Total %.2f s is spent."%(mode, end-start))
        print("\tError %.4e has been reached, total iterations is %d ."%(error, iteration))
        print("\tError with analytic solution is %.8e ."%error_analytic_record[-1])
    #     phi = np.array(phi.reshape(N,N))

    data = np.vstack((np.array(N_range),np.array(iteration_record), np.array(error_analytic_record), \
                      np.array(total_time_record))).T
    with open('Error_vs_Lattice_Size_%s_Criteria=%.8e.txt'%(mode,criteria), 'w') as f:
        np.savetxt(f, data, fmt="%.8e",\
                   header='Lattice Size\tIteration(s)\tError\tTotal_Time (s)',\
                   footer='Stopping Criteria: %.8e'%criteria)
# Out:
# Lattice size = 16 using jacobi scheme:
# 	Simulation of jacobi scheme ends. Total 0.06 s is spent.
# 	Error 9.7639e-22 has been reached, total iterations is 2029 .
# 	Error with analytic solution is 1.64406205e-03 .
# Lattice size = 32 using jacobi scheme:
# 	Simulation of jacobi scheme ends. Total 0.39 s is spent.
# 	Error 9.9025e-22 has been reached, total iterations is 8347 .
# 	Error with analytic solution is 4.32943368e-04 .
# Lattice size = 64 using jacobi scheme:
# 	Simulation of jacobi scheme ends. Total 3.51 s is spent.
# 	Error 9.9867e-22 has been reached, total iterations is 33207 .
# 	Error with analytic solution is 1.10761037e-04 .
# Lattice size = 128 using jacobi scheme:
# 	Simulation of jacobi scheme ends. Total 43.42 s is spent.
# 	Error 9.9970e-22 has been reached, total iterations is 130083 .
# 	Error with analytic solution is 2.79882493e-05 .
# Lattice size = 256 using jacobi scheme:
# 	Simulation of jacobi scheme ends. Total 659.10 s is spent.
# 	Error 9.9971e-22 has been reached, total iterations is 505895 .
# 	Error with analytic solution is 7.03307799e-06 .

# %%
scheme_list = []
data_list = []
for file in os.listdir('./'):
    if "Error" in file:
        if 'jacobi' in file:
            scheme_list.append('Jacobi')
            data_list.append(np.loadtxt('%s'%file))
        elif 'gauss_seidel' in file:
            scheme_list.append('Gauss-Seidel')
            data_list.append(np.loadtxt('%s'%file))
        elif 'SOR' in file:
            scheme_list.append('SOR')
            data_list.append(np.loadtxt('%s'%file))
dict_data = dict(zip(scheme_list, data_list))

# %%
from scipy.optimize import curve_fit

def linear_fit(x, a, b):
    return a*x+b

count = 0 
fig = plt.figure(figsize=(3*3,3), dpi=200)
plt.subplots_adjust(wspace=0.6)
ax_1 = plt.subplot(131)
ax_2 = plt.subplot(132)
ax_3 = plt.subplot(133)
for scheme in list(dict_data.keys()):
    data_lattice_size = np.log2(dict_data[scheme][:,0])
    data_iteration = np.log2(dict_data[scheme][:,1])
    data_error = np.log2(dict_data[scheme][:,2])
    data_total_time = np.log2(dict_data[scheme][:,3])
    
    ax_1.plot(data_lattice_size, data_error, lw=0.0, marker='o', markersize=2.0, label="%s"%scheme)
    if count==0:
        prop, pocp = curve_fit(linear_fit, data_lattice_size, data_error)
        ax_1.plot(data_lattice_size, prop[0]*data_lattice_size+prop[1], lw = 0.5, ls='--', c='red')
        ax_1.text(5.5, -12.0,"slope = %.4f"%prop[0], fontsize=8.0)
    
    ax_2.plot(data_lattice_size, data_iteration, lw=0.0, marker='o', markersize=2.0, label="%s"%scheme)
    prop, pocp = curve_fit(linear_fit, data_lattice_size, data_iteration)
    
    if scheme == 'SOR':
        ax_2.plot(data_lattice_size, prop[0]*data_lattice_size+prop[1], lw = 0.5, ls='--', c='blue')
        ax_2.text(5.5, 12.0,"slope of %s = %.4f"%(scheme, prop[0]), fontsize=8.0)
    elif scheme == 'Gauss-Seidel':
        ax_2.plot(data_lattice_size, prop[0]*data_lattice_size+prop[1], lw = 0.5, ls='--', c='lime')
        ax_2.text(3.5, 14.2,"slope of %s = %.4f"%(scheme, prop[0]), fontsize=8.0)
    else:
        ax_2.plot(data_lattice_size, prop[0]*data_lattice_size+prop[1], lw = 0.5, ls='--', c='gold')
        ax_2.text(4.5, 16.5,"slope of %s = %.4f"%(scheme, prop[0]), fontsize=8.0)
    ax_3.plot(data_lattice_size, data_total_time, lw=0.0, marker='o', markersize=2.0, label="%s"%scheme)    
    prop, pocp = curve_fit(linear_fit, data_lattice_size, data_total_time)
    
    if scheme == 'SOR':
        ax_3.plot(data_lattice_size, prop[0]*data_lattice_size+prop[1], lw = 0.5, ls='--', c='blue')
        ax_3.text(6.7, 2.0,"slope of %s = %.4f"%(scheme, prop[0]), fontsize=8.0)
    elif scheme == 'Gauss-Seidel':
        ax_3.plot(data_lattice_size, prop[0]*data_lattice_size+prop[1], lw = 0.5, ls='--', c='lime')
        ax_3.text(7.5, 4.5,"slope of %s = %.4f"%(scheme, prop[0]), fontsize=8.0)
    else:
        ax_3.plot(data_lattice_size, prop[0]*data_lattice_size+prop[1], lw = 0.5, ls='--', c='gold')
        ax_3.text(4.0, 5.8,"slope of %s = %.4f"%(scheme, prop[0]), fontsize=8.0)
    count += 1
ax_1.set_xlabel('$log_2N$', fontsize=12.)
ax_1.set_ylabel('$log_2$Error', fontsize=12.)
ax_1.set_title('$log_2-log_2$ Error v.s. $N$',y=1.03)
ax_1.legend(loc='upper right', prop={'size':5.0})
ax_2.set_xlabel('$log_2N$', fontsize=12.)
ax_2.set_ylabel('$log_2$ Iterations', fontsize=12.)
ax_2.set_title('$log_2-log_2$ Iterations v.s. $N$',y=1.03)
ax_2.legend(loc='upper left', prop={'size':5.0})
ax_3.set_xlabel('$log_2N$', fontsize=12.)
ax_3.set_ylabel('$log_2$ Clock-Time', fontsize=12.)
ax_3.set_title('$log_2-log_2$ Clock-Time v.s. $N$',y=1.03)
ax_3.legend(loc='upper left', prop={'size':5.0})
plt.savefig("/home/lab/Guan_Ming/Computational_Astrophysics/Homework/HW3/Problem_1_lattice_size_v.s.error_iterations_clock-time.png", bbox_inches='tight', dpi=200, pad_inches=0.05)

# %% [markdown]
# ### Optimal $\omega$ Test

# %%
L = 1.0
iteration_max = 1000000
criteria = 1.e-21
N_range = np.array([16, 32, 64, 128])
# show_error_interval = 10000

try: 
    os.makedirs('./Optimal_Omega_Test_Fixed_Boundary_L=1')
except:
    print("Folder already existed!")
path = './Optimal_Omega_Test_Fixed_Boundary_L=1/'

for N in N_range:
    k = 2.0*np.pi*3.0/N
    x = np.arange(0,N)
    y = np.arange(0,N)
    xx,yy= np.meshgrid(x,y)

    phi_analytic = np.exp(-k*xx)*np.sin(k*yy)

    rho = np.zeros(N*N)
    boundary = ((yy%N==0) | (yy%N==N-1) | (xx%N==0) | (xx%N==N-1)).ravel()
    
    dx = L/N
    
    omega_range = np.arange(0.25, 1.33, 0.01)

    neighbor_r = np.arange(N*N)
    neighbor_l = np.arange(N*N)
    neighbor_u = np.arange(N*N)
    neighbor_d = np.arange(N*N)
    neighbor_r = N*(neighbor_r//N) + (neighbor_r%N+1)%N
    neighbor_l = N*(neighbor_l//N) + (neighbor_l%N+N-1)%N
    neighbor_u = N*((neighbor_u//N+1)%N) + neighbor_u%N
    neighbor_d = N*((neighbor_d//N+N-1)%N) + neighbor_d%N

    idx_all = np.argwhere(boundary==False).reshape(-1)
    idx_even = idx_all[idx_all%2==0]
    idx_odd = idx_all[idx_all%2==1]

    iteration_record = []
    total_time_record = []
    error_record = []

    print("Test the optimal omega for SOR scheme with N=%d ."%N)
    for omega in omega_range:
        ### reinitialize the field and parameters
        phi = np.zeros(N*N)
        phi[boundary] = phi_analytic.ravel()[boundary]
        iteration = 0
        error = CALCULATE_CRITERIA(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)
        ###

        start = time.time()
        while error>criteria and iteration<iteration_max: 
            phi = LAPLACIAN_SUCCESSIVE_OVER_RELAXATION(phi, omega, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d, idx_even, idx_odd)
            error = CALCULATE_CRITERIA(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)
            iteration += 1
#             if iteration%show_error_interval == 0:
#                 print("\tIteration = %d, error = %.4e ."%(iteration, error))
        end = time.time()
        print("\tSimulation of omega = %.4e ends. Total %.2f s is spent."%(omega, end-start))
        print("\tError %.4e has been reached, total iterations is %d ."%(error, iteration))
        iteration_record.append(iteration)
        total_time_record.append(end-start)
        error_record.append(error)
        
    error_record = np.array(error_record)
    iteration_record = np.array(iteration_record)
    total_time_record = np.array(total_time_record)

    data = np.vstack((omega_range, iteration_record,error_record, total_time_record)).T
    np.savetxt('%sN=%d_criteria=%.8e_optimal_omega_record.txt'%(path, N, criteria), data, fmt="%.8e",\
               header='Omega\tIteration(s)\tError\tTotal_Time (s)',\
               footer='Stopping Criteria: %.8e'%criteria)
# Out:
# Folder already existed!
# Test the optimal omega for SOR scheme with N=16 .
# 	Simulation of omega = 2.5000e-01 ends. Total 0.13 s is spent.
# 	Error 9.9841e-22 has been reached, total iterations is 3481 .
# 	Simulation of omega = 2.6000e-01 ends. Total 0.12 s is spent.
# 	Error 9.9862e-22 has been reached, total iterations is 3338 .
# 	Simulation of omega = 2.7000e-01 ends. Total 0.11 s is spent.
# 	Error 9.9370e-22 has been reached, total iterations is 3206 .
# 	Simulation of omega = 2.8000e-01 ends. Total 0.11 s is spent.
# 	Error 9.9435e-22 has been reached, total iterations is 3083 .
# 	Simulation of omega = 2.9000e-01 ends. Total 0.11 s is spent.
# 	Error 9.8801e-22 has been reached, total iterations is 2969 .
# 	Simulation of omega = 3.0000e-01 ends. Total 0.10 s is spent.
# 	Error 9.9007e-22 has been reached, total iterations is 2862 .
# 	Simulation of omega = 3.1000e-01 ends. Total 0.10 s is spent.
# 	Error 9.9075e-22 has been reached, total iterations is 2762 .
# 	Simulation of omega = 3.2000e-01 ends. Total 0.10 s is spent.
# 	Error 9.9520e-22 has been reached, total iterations is 2668 .
# 	Simulation of omega = 3.3000e-01 ends. Total 0.09 s is spent.
# 	Error 9.9496e-22 has been reached, total iterations is 2580 .
# 	Simulation of omega = 3.4000e-01 ends. Total 0.09 s is spent.
# 	Error 9.9755e-22 has been reached, total iterations is 2497 .
# 	Simulation of omega = 3.5000e-01 ends. Total 0.09 s is spent.
# 	Error 9.9587e-22 has been reached, total iterations is 2419 .
# 	Simulation of omega = 3.6000e-01 ends. Total 0.08 s is spent.
# 	Error 9.9997e-22 has been reached, total iterations is 2345 .
# 	Simulation of omega = 3.7000e-01 ends. Total 0.08 s is spent.
# 	Error 9.8632e-22 has been reached, total iterations is 2276 .
# 	Simulation of omega = 3.8000e-01 ends. Total 0.08 s is spent.
# 	Error 9.8413e-22 has been reached, total iterations is 2210 .
# 	Simulation of omega = 3.9000e-01 ends. Total 0.08 s is spent.
# 	Error 9.8913e-22 has been reached, total iterations is 2147 .
# 	Simulation of omega = 4.0000e-01 ends. Total 0.07 s is spent.
# 	Error 9.9708e-22 has been reached, total iterations is 2087 .
# 	Simulation of omega = 4.1000e-01 ends. Total 0.07 s is spent.
# 	Error 9.8380e-22 has been reached, total iterations is 2031 .
# 	Simulation of omega = 4.2000e-01 ends. Total 0.07 s is spent.
# 	Error 9.8398e-22 has been reached, total iterations is 1977 .
# 	Simulation of omega = 4.3000e-01 ends. Total 0.07 s is spent.
# 	Error 9.9489e-22 has been reached, total iterations is 1925 .
# 	Simulation of omega = 4.4000e-01 ends. Total 0.07 s is spent.
# 	Error 9.9221e-22 has been reached, total iterations is 1876 .
# 	Simulation of omega = 4.5000e-01 ends. Total 0.07 s is spent.
# 	Error 9.9345e-22 has been reached, total iterations is 1829 .
# 	Simulation of omega = 4.6000e-01 ends. Total 0.06 s is spent.
# 	Error 9.9566e-22 has been reached, total iterations is 1784 .
# 	Simulation of omega = 4.7000e-01 ends. Total 0.06 s is spent.
# 	Error 9.9592e-22 has been reached, total iterations is 1741 .
# 	Simulation of omega = 4.8000e-01 ends. Total 0.06 s is spent.
# 	Error 9.9123e-22 has been reached, total iterations is 1700 .
# 	Simulation of omega = 4.9000e-01 ends. Total 0.06 s is spent.
# 	Error 9.7869e-22 has been reached, total iterations is 1661 .
# 	Simulation of omega = 5.0000e-01 ends. Total 0.06 s is spent.
# 	Error 9.7985e-22 has been reached, total iterations is 1623 .
# 	Simulation of omega = 5.1000e-01 ends. Total 0.06 s is spent.
# 	Error 9.9349e-22 has been reached, total iterations is 1586 .
# 	Simulation of omega = 5.2000e-01 ends. Total 0.06 s is spent.
# 	Error 9.9227e-22 has been reached, total iterations is 1551 .
# 	Simulation of omega = 5.3000e-01 ends. Total 0.05 s is spent.
# 	Error 9.9958e-22 has been reached, total iterations is 1517 .
# 	Simulation of omega = 5.4000e-01 ends. Total 0.05 s is spent.
# 	Error 9.8679e-22 has been reached, total iterations is 1485 .
# 	Simulation of omega = 5.5000e-01 ends. Total 0.05 s is spent.
# 	Error 9.7853e-22 has been reached, total iterations is 1454 .
# 	Simulation of omega = 5.6000e-01 ends. Total 0.05 s is spent.
# 	Error 9.7330e-22 has been reached, total iterations is 1424 .
# 	Simulation of omega = 5.7000e-01 ends. Total 0.05 s is spent.
# 	Error 9.9822e-22 has been reached, total iterations is 1394 .
# 	Simulation of omega = 5.8000e-01 ends. Total 0.05 s is spent.
# 	Error 9.9494e-22 has been reached, total iterations is 1366 .
# 	Simulation of omega = 5.9000e-01 ends. Total 0.05 s is spent.
# 	Error 9.9012e-22 has been reached, total iterations is 1339 .
# 	Simulation of omega = 6.0000e-01 ends. Total 0.05 s is spent.
# 	Error 9.8225e-22 has been reached, total iterations is 1313 .
# 	Simulation of omega = 6.1000e-01 ends. Total 0.05 s is spent.
# 	Error 9.6985e-22 has been reached, total iterations is 1288 .
# 	Simulation of omega = 6.2000e-01 ends. Total 0.04 s is spent.
# 	Error 9.8274e-22 has been reached, total iterations is 1263 .
# 	Simulation of omega = 6.3000e-01 ends. Total 0.04 s is spent.
# 	Error 9.8919e-22 has been reached, total iterations is 1239 .
# 	Simulation of omega = 6.4000e-01 ends. Total 0.04 s is spent.
# 	Error 9.8739e-22 has been reached, total iterations is 1216 .
# 	Simulation of omega = 6.5000e-01 ends. Total 0.04 s is spent.
# 	Error 9.7583e-22 has been reached, total iterations is 1194 .
# 	Simulation of omega = 6.6000e-01 ends. Total 0.04 s is spent.
# 	Error 9.8691e-22 has been reached, total iterations is 1172 .
# 	Simulation of omega = 6.7000e-01 ends. Total 0.04 s is spent.
# 	Error 9.8615e-22 has been reached, total iterations is 1151 .
# 	Simulation of omega = 6.8000e-01 ends. Total 0.04 s is spent.
# 	Error 9.7192e-22 has been reached, total iterations is 1131 .
# 	Simulation of omega = 6.9000e-01 ends. Total 0.04 s is spent.
# 	Error 9.7836e-22 has been reached, total iterations is 1111 .
# 	Simulation of omega = 7.0000e-01 ends. Total 0.04 s is spent.
# 	Error 9.6926e-22 has been reached, total iterations is 1092 .
# 	Simulation of omega = 7.1000e-01 ends. Total 0.04 s is spent.
# 	Error 9.7989e-22 has been reached, total iterations is 1073 .
# 	Simulation of omega = 7.2000e-01 ends. Total 0.04 s is spent.
# 	Error 9.7286e-22 has been reached, total iterations is 1055 .
# 	Simulation of omega = 7.3000e-01 ends. Total 0.04 s is spent.
# 	Error 9.8467e-22 has been reached, total iterations is 1037 .
# 	Simulation of omega = 7.4000e-01 ends. Total 0.04 s is spent.
# 	Error 9.7648e-22 has been reached, total iterations is 1020 .
# 	Simulation of omega = 7.5000e-01 ends. Total 0.04 s is spent.
# 	Error 9.8630e-22 has been reached, total iterations is 1003 .
# 	Simulation of omega = 7.6000e-01 ends. Total 0.04 s is spent.
# 	Error 9.7381e-22 has been reached, total iterations is 987 .
# 	Simulation of omega = 7.7000e-01 ends. Total 0.03 s is spent.
# 	Error 9.7830e-22 has been reached, total iterations is 971 .
# 	Simulation of omega = 7.8000e-01 ends. Total 0.03 s is spent.
# 	Error 9.5844e-22 has been reached, total iterations is 956 .
# 	Simulation of omega = 7.9000e-01 ends. Total 0.03 s is spent.
# 	Error 9.9672e-22 has been reached, total iterations is 940 .
# 	Simulation of omega = 8.0000e-01 ends. Total 0.03 s is spent.
# 	Error 9.6625e-22 has been reached, total iterations is 926 .
# 	Simulation of omega = 8.1000e-01 ends. Total 0.03 s is spent.
# 	Error 9.9463e-22 has been reached, total iterations is 911 .
# 	Simulation of omega = 8.2000e-01 ends. Total 0.03 s is spent.
# 	Error 9.9495e-22 has been reached, total iterations is 897 .
# 	Simulation of omega = 8.3000e-01 ends. Total 0.03 s is spent.
# 	Error 9.6533e-22 has been reached, total iterations is 884 .
# 	Simulation of omega = 8.4000e-01 ends. Total 0.03 s is spent.
# 	Error 9.9559e-22 has been reached, total iterations is 870 .
# 	Simulation of omega = 8.5000e-01 ends. Total 0.03 s is spent.
# 	Error 9.9478e-22 has been reached, total iterations is 857 .
# 	Simulation of omega = 8.6000e-01 ends. Total 0.03 s is spent.
# 	Error 9.6111e-22 has been reached, total iterations is 845 .
# 	Simulation of omega = 8.7000e-01 ends. Total 0.03 s is spent.
# 	Error 9.8817e-22 has been reached, total iterations is 832 .
# 	Simulation of omega = 8.8000e-01 ends. Total 0.03 s is spent.
# 	Error 9.8123e-22 has been reached, total iterations is 820 .
# 	Simulation of omega = 8.9000e-01 ends. Total 0.03 s is spent.
# 	Error 9.8765e-22 has been reached, total iterations is 808 .
# 	Simulation of omega = 9.0000e-01 ends. Total 0.03 s is spent.
# 	Error 9.5752e-22 has been reached, total iterations is 797 .
# 	Simulation of omega = 9.1000e-01 ends. Total 0.03 s is spent.
# 	Error 9.8990e-22 has been reached, total iterations is 785 .
# 	Simulation of omega = 9.2000e-01 ends. Total 0.03 s is spent.
# 	Error 9.8456e-22 has been reached, total iterations is 774 .
# 	Simulation of omega = 9.3000e-01 ends. Total 0.03 s is spent.
# 	Error 9.9163e-22 has been reached, total iterations is 763 .
# 	Simulation of omega = 9.4000e-01 ends. Total 0.03 s is spent.
# 	Error 9.5823e-22 has been reached, total iterations is 753 .
# 	Simulation of omega = 9.5000e-01 ends. Total 0.03 s is spent.
# 	Error 9.8935e-22 has been reached, total iterations is 742 .
# 	Simulation of omega = 9.6000e-01 ends. Total 0.03 s is spent.
# 	Error 9.7880e-22 has been reached, total iterations is 732 .
# 	Simulation of omega = 9.7000e-01 ends. Total 0.03 s is spent.
# 	Error 9.7958e-22 has been reached, total iterations is 722 .
# 	Simulation of omega = 9.8000e-01 ends. Total 0.03 s is spent.
# 	Error 9.9193e-22 has been reached, total iterations is 712 .
# 	Simulation of omega = 9.9000e-01 ends. Total 0.03 s is spent.
# 	Error 9.5903e-22 has been reached, total iterations is 703 .
# 	Simulation of omega = 1.0000e+00 ends. Total 0.03 s is spent.
# 	Error 9.9365e-22 has been reached, total iterations is 693 .
# 	Simulation of omega = 1.0100e+00 ends. Total 0.02 s is spent.
# 	Error 9.8168e-22 has been reached, total iterations is 684 .
# 	Simulation of omega = 1.0200e+00 ends. Total 0.02 s is spent.
# 	Error 9.8015e-22 has been reached, total iterations is 675 .
# 	Simulation of omega = 1.0300e+00 ends. Total 0.02 s is spent.
# 	Error 9.8915e-22 has been reached, total iterations is 666 .
# 	Simulation of omega = 1.0400e+00 ends. Total 0.02 s is spent.
# 	Error 9.4835e-22 has been reached, total iterations is 658 .
# 	Simulation of omega = 1.0500e+00 ends. Total 0.02 s is spent.
# 	Error 9.7727e-22 has been reached, total iterations is 649 .
# 	Simulation of omega = 1.0600e+00 ends. Total 0.02 s is spent.
# 	Error 9.5536e-22 has been reached, total iterations is 641 .
# 	Simulation of omega = 1.0700e+00 ends. Total 0.02 s is spent.
# 	Error 9.4288e-22 has been reached, total iterations is 633 .
# 	Simulation of omega = 1.0800e+00 ends. Total 0.02 s is spent.
# 	Error 9.3949e-22 has been reached, total iterations is 625 .
# 	Simulation of omega = 1.0900e+00 ends. Total 0.02 s is spent.
# 	Error 9.4521e-22 has been reached, total iterations is 617 .
# 	Simulation of omega = 1.1000e+00 ends. Total 0.02 s is spent.
# 	Error 9.6038e-22 has been reached, total iterations is 609 .
# 	Simulation of omega = 1.1100e+00 ends. Total 0.02 s is spent.
# 	Error 9.8548e-22 has been reached, total iterations is 601 .
# 	Simulation of omega = 1.1200e+00 ends. Total 0.02 s is spent.
# 	Error 9.5347e-22 has been reached, total iterations is 594 .
# 	Simulation of omega = 1.1300e+00 ends. Total 0.02 s is spent.
# 	Error 9.9741e-22 has been reached, total iterations is 586 .
# 	Simulation of omega = 1.1400e+00 ends. Total 0.02 s is spent.
# 	Error 9.8229e-22 has been reached, total iterations is 579 .
# 	Simulation of omega = 1.1500e+00 ends. Total 0.02 s is spent.
# 	Error 9.7572e-22 has been reached, total iterations is 572 .
# 	Simulation of omega = 1.1600e+00 ends. Total 0.02 s is spent.
# 	Error 9.7762e-22 has been reached, total iterations is 565 .
# 	Simulation of omega = 1.1700e+00 ends. Total 0.02 s is spent.
# 	Error 9.8815e-22 has been reached, total iterations is 558 .
# 	Simulation of omega = 1.1800e+00 ends. Total 0.02 s is spent.
# 	Error 9.3572e-22 has been reached, total iterations is 552 .
# 	Simulation of omega = 1.1900e+00 ends. Total 0.02 s is spent.
# 	Error 9.6191e-22 has been reached, total iterations is 545 .
# 	Simulation of omega = 1.2000e+00 ends. Total 0.02 s is spent.
# 	Error 9.9786e-22 has been reached, total iterations is 538 .
# 	Simulation of omega = 1.2100e+00 ends. Total 0.02 s is spent.
# 	Error 9.6740e-22 has been reached, total iterations is 532 .
# 	Simulation of omega = 1.2200e+00 ends. Total 0.02 s is spent.
# 	Error 9.4478e-22 has been reached, total iterations is 526 .
# 	Simulation of omega = 1.2300e+00 ends. Total 0.02 s is spent.
# 	Error 9.2965e-22 has been reached, total iterations is 520 .
# 	Simulation of omega = 1.2400e+00 ends. Total 0.02 s is spent.
# 	Error 9.9817e-22 has been reached, total iterations is 513 .
# 	Simulation of omega = 1.2500e+00 ends. Total 0.02 s is spent.
# 	Error 9.9818e-22 has been reached, total iterations is 507 .
# 	Simulation of omega = 1.2600e+00 ends. Total 0.02 s is spent.
# 	Error 9.2719e-22 has been reached, total iterations is 502 .
# 	Simulation of omega = 1.2700e+00 ends. Total 0.02 s is spent.
# 	Error 9.4086e-22 has been reached, total iterations is 496 .
# 	Simulation of omega = 1.2800e+00 ends. Total 0.02 s is spent.
# 	Error 9.6233e-22 has been reached, total iterations is 490 .
# 	Simulation of omega = 1.2900e+00 ends. Total 0.02 s is spent.
# 	Error 9.9225e-22 has been reached, total iterations is 484 .
# 	Simulation of omega = 1.3000e+00 ends. Total 0.02 s is spent.
# 	Error 9.4688e-22 has been reached, total iterations is 479 .
# 	Simulation of omega = 1.3100e+00 ends. Total 0.02 s is spent.
# 	Error 8.8223e-22 has been reached, total iterations is 483 .
# 	Simulation of omega = 1.3200e+00 ends. Total 0.02 s is spent.
# 	Error 9.0564e-22 has been reached, total iterations is 689 .
# Test the optimal omega for SOR scheme with N=32 .
# 	Simulation of omega = 2.5000e-01 ends. Total 0.83 s is spent.
# 	Error 9.9888e-22 has been reached, total iterations is 13676 .
# 	Simulation of omega = 2.6000e-01 ends. Total 0.79 s is spent.
# 	Error 9.9873e-22 has been reached, total iterations is 13115 .
# 	Simulation of omega = 2.7000e-01 ends. Total 0.76 s is spent.
# 	Error 9.9725e-22 has been reached, total iterations is 12596 .
# 	Simulation of omega = 2.8000e-01 ends. Total 0.74 s is spent.
# 	Error 9.9906e-22 has been reached, total iterations is 12113 .
# 	Simulation of omega = 2.9000e-01 ends. Total 0.71 s is spent.
# 	Error 9.9866e-22 has been reached, total iterations is 11664 .
# 	Simulation of omega = 3.0000e-01 ends. Total 0.69 s is spent.
# 	Error 9.9803e-22 has been reached, total iterations is 11245 .
# 	Simulation of omega = 3.1000e-01 ends. Total 0.66 s is spent.
# 	Error 9.9766e-22 has been reached, total iterations is 10853 .
# 	Simulation of omega = 3.2000e-01 ends. Total 0.64 s is spent.
# 	Error 9.9902e-22 has been reached, total iterations is 10485 .
# 	Simulation of omega = 3.3000e-01 ends. Total 0.61 s is spent.
# 	Error 9.9779e-22 has been reached, total iterations is 10140 .
# 	Simulation of omega = 3.4000e-01 ends. Total 0.59 s is spent.
# 	Error 9.9771e-22 has been reached, total iterations is 9815 .
# 	Simulation of omega = 3.5000e-01 ends. Total 0.58 s is spent.
# 	Error 9.9988e-22 has been reached, total iterations is 9508 .
# 	Simulation of omega = 3.6000e-01 ends. Total 0.56 s is spent.
# 	Error 9.9829e-22 has been reached, total iterations is 9219 .
# 	Simulation of omega = 3.7000e-01 ends. Total 0.54 s is spent.
# 	Error 9.9927e-22 has been reached, total iterations is 8945 .
# 	Simulation of omega = 3.8000e-01 ends. Total 0.53 s is spent.
# 	Error 9.9777e-22 has been reached, total iterations is 8686 .
# 	Simulation of omega = 3.9000e-01 ends. Total 0.51 s is spent.
# 	Error 9.9758e-22 has been reached, total iterations is 8440 .
# 	Simulation of omega = 4.0000e-01 ends. Total 0.50 s is spent.
# 	Error 9.9872e-22 has been reached, total iterations is 8206 .
# 	Simulation of omega = 4.1000e-01 ends. Total 0.49 s is spent.
# 	Error 9.9713e-22 has been reached, total iterations is 7984 .
# 	Simulation of omega = 4.2000e-01 ends. Total 0.48 s is spent.
# 	Error 9.9832e-22 has been reached, total iterations is 7772 .
# 	Simulation of omega = 4.3000e-01 ends. Total 0.46 s is spent.
# 	Error 9.9883e-22 has been reached, total iterations is 7570 .
# 	Simulation of omega = 4.4000e-01 ends. Total 0.45 s is spent.
# 	Error 9.9523e-22 has been reached, total iterations is 7378 .
# 	Simulation of omega = 4.5000e-01 ends. Total 0.44 s is spent.
# 	Error 9.9955e-22 has been reached, total iterations is 7193 .
# 	Simulation of omega = 4.6000e-01 ends. Total 0.43 s is spent.
# 	Error 9.9885e-22 has been reached, total iterations is 7017 .
# 	Simulation of omega = 4.7000e-01 ends. Total 0.42 s is spent.
# 	Error 9.9539e-22 has been reached, total iterations is 6849 .
# 	Simulation of omega = 4.8000e-01 ends. Total 0.41 s is spent.
# 	Error 9.9751e-22 has been reached, total iterations is 6687 .
# 	Simulation of omega = 4.9000e-01 ends. Total 0.40 s is spent.
# 	Error 9.9742e-22 has been reached, total iterations is 6532 .
# 	Simulation of omega = 5.0000e-01 ends. Total 0.39 s is spent.
# 	Error 9.9838e-22 has been reached, total iterations is 6383 .
# 	Simulation of omega = 5.1000e-01 ends. Total 0.38 s is spent.
# 	Error 9.9870e-22 has been reached, total iterations is 6240 .
# 	Simulation of omega = 5.2000e-01 ends. Total 0.37 s is spent.
# 	Error 9.9588e-22 has been reached, total iterations is 6103 .
# 	Simulation of omega = 5.3000e-01 ends. Total 0.36 s is spent.
# 	Error 9.9409e-22 has been reached, total iterations is 5971 .
# 	Simulation of omega = 5.4000e-01 ends. Total 0.36 s is spent.
# 	Error 9.9796e-22 has been reached, total iterations is 5843 .
# 	Simulation of omega = 5.5000e-01 ends. Total 0.34 s is spent.
# 	Error 9.9963e-22 has been reached, total iterations is 5720 .
# 	Simulation of omega = 5.6000e-01 ends. Total 0.34 s is spent.
# 	Error 9.9730e-22 has been reached, total iterations is 5602 .
# 	Simulation of omega = 5.7000e-01 ends. Total 0.33 s is spent.
# 	Error 9.9592e-22 has been reached, total iterations is 5488 .
# 	Simulation of omega = 5.8000e-01 ends. Total 0.33 s is spent.
# 	Error 9.9406e-22 has been reached, total iterations is 5378 .
# 	Simulation of omega = 5.9000e-01 ends. Total 0.32 s is spent.
# 	Error 9.9734e-22 has been reached, total iterations is 5271 .
# 	Simulation of omega = 6.0000e-01 ends. Total 0.31 s is spent.
# 	Error 9.9758e-22 has been reached, total iterations is 5168 .
# 	Simulation of omega = 6.1000e-01 ends. Total 0.31 s is spent.
# 	Error 9.9325e-22 has been reached, total iterations is 5069 .
# 	Simulation of omega = 6.2000e-01 ends. Total 0.30 s is spent.
# 	Error 9.9783e-22 has been reached, total iterations is 4972 .
# 	Simulation of omega = 6.3000e-01 ends. Total 0.29 s is spent.
# 	Error 9.9545e-22 has been reached, total iterations is 4879 .
# 	Simulation of omega = 6.4000e-01 ends. Total 0.29 s is spent.
# 	Error 9.9234e-22 has been reached, total iterations is 4789 .
# 	Simulation of omega = 6.5000e-01 ends. Total 0.28 s is spent.
# 	Error 9.9534e-22 has been reached, total iterations is 4701 .
# 	Simulation of omega = 6.6000e-01 ends. Total 0.28 s is spent.
# 	Error 9.9565e-22 has been reached, total iterations is 4616 .
# 	Simulation of omega = 6.7000e-01 ends. Total 0.27 s is spent.
# 	Error 9.9218e-22 has been reached, total iterations is 4534 .
# 	Simulation of omega = 6.8000e-01 ends. Total 0.27 s is spent.
# 	Error 9.9219e-22 has been reached, total iterations is 4454 .
# 	Simulation of omega = 6.9000e-01 ends. Total 0.26 s is spent.
# 	Error 9.9488e-22 has been reached, total iterations is 4376 .
# 	Simulation of omega = 7.0000e-01 ends. Total 0.26 s is spent.
# 	Error 9.9961e-22 has been reached, total iterations is 4300 .
# 	Simulation of omega = 7.1000e-01 ends. Total 0.25 s is spent.
# 	Error 9.9685e-22 has been reached, total iterations is 4227 .
# 	Simulation of omega = 7.2000e-01 ends. Total 0.25 s is spent.
# 	Error 9.9431e-22 has been reached, total iterations is 4156 .
# 	Simulation of omega = 7.3000e-01 ends. Total 0.25 s is spent.
# 	Error 9.9128e-22 has been reached, total iterations is 4087 .
# 	Simulation of omega = 7.4000e-01 ends. Total 0.24 s is spent.
# 	Error 9.9624e-22 has been reached, total iterations is 4019 .
# 	Simulation of omega = 7.5000e-01 ends. Total 0.24 s is spent.
# 	Error 9.9949e-22 has been reached, total iterations is 3953 .
# 	Simulation of omega = 7.6000e-01 ends. Total 0.24 s is spent.
# 	Error 9.9073e-22 has been reached, total iterations is 3890 .
# 	Simulation of omega = 7.7000e-01 ends. Total 0.23 s is spent.
# 	Error 9.9783e-22 has been reached, total iterations is 3827 .
# 	Simulation of omega = 7.8000e-01 ends. Total 0.23 s is spent.
# 	Error 9.9132e-22 has been reached, total iterations is 3767 .
# 	Simulation of omega = 7.9000e-01 ends. Total 0.22 s is spent.
# 	Error 9.9000e-22 has been reached, total iterations is 3708 .
# 	Simulation of omega = 8.0000e-01 ends. Total 0.22 s is spent.
# 	Error 9.9353e-22 has been reached, total iterations is 3650 .
# 	Simulation of omega = 8.1000e-01 ends. Total 0.22 s is spent.
# 	Error 9.9119e-22 has been reached, total iterations is 3594 .
# 	Simulation of omega = 8.2000e-01 ends. Total 0.21 s is spent.
# 	Error 9.9275e-22 has been reached, total iterations is 3539 .
# 	Simulation of omega = 8.3000e-01 ends. Total 0.21 s is spent.
# 	Error 9.9782e-22 has been reached, total iterations is 3485 .
# 	Simulation of omega = 8.4000e-01 ends. Total 0.21 s is spent.
# 	Error 9.9513e-22 has been reached, total iterations is 3433 .
# 	Simulation of omega = 8.5000e-01 ends. Total 0.20 s is spent.
# 	Error 9.9493e-22 has been reached, total iterations is 3382 .
# 	Simulation of omega = 8.6000e-01 ends. Total 0.20 s is spent.
# 	Error 9.9686e-22 has been reached, total iterations is 3332 .
# 	Simulation of omega = 8.7000e-01 ends. Total 0.20 s is spent.
# 	Error 9.8916e-22 has been reached, total iterations is 3284 .
# 	Simulation of omega = 8.8000e-01 ends. Total 0.20 s is spent.
# 	Error 9.9398e-22 has been reached, total iterations is 3236 .
# 	Simulation of omega = 8.9000e-01 ends. Total 0.19 s is spent.
# 	Error 9.9980e-22 has been reached, total iterations is 3189 .
# 	Simulation of omega = 9.0000e-01 ends. Total 0.19 s is spent.
# 	Error 9.9430e-22 has been reached, total iterations is 3144 .
# 	Simulation of omega = 9.1000e-01 ends. Total 0.19 s is spent.
# 	Error 9.8870e-22 has been reached, total iterations is 3100 .
# 	Simulation of omega = 9.2000e-01 ends. Total 0.19 s is spent.
# 	Error 9.9473e-22 has been reached, total iterations is 3056 .
# 	Simulation of omega = 9.3000e-01 ends. Total 0.18 s is spent.
# 	Error 9.8781e-22 has been reached, total iterations is 3014 .
# 	Simulation of omega = 9.4000e-01 ends. Total 0.18 s is spent.
# 	Error 9.9203e-22 has been reached, total iterations is 2972 .
# 	Simulation of omega = 9.5000e-01 ends. Total 0.18 s is spent.
# 	Error 9.9483e-22 has been reached, total iterations is 2931 .
# 	Simulation of omega = 9.6000e-01 ends. Total 0.17 s is spent.
# 	Error 9.9583e-22 has been reached, total iterations is 2891 .
# 	Simulation of omega = 9.7000e-01 ends. Total 0.17 s is spent.
# 	Error 9.9452e-22 has been reached, total iterations is 2852 .
# 	Simulation of omega = 9.8000e-01 ends. Total 0.17 s is spent.
# 	Error 9.9052e-22 has been reached, total iterations is 2814 .
# 	Simulation of omega = 9.9000e-01 ends. Total 0.17 s is spent.
# 	Error 9.9689e-22 has been reached, total iterations is 2776 .
# 	Simulation of omega = 1.0000e+00 ends. Total 0.17 s is spent.
# 	Error 9.8641e-22 has been reached, total iterations is 2740 .
# 	Simulation of omega = 1.0100e+00 ends. Total 0.16 s is spent.
# 	Error 9.9949e-22 has been reached, total iterations is 2703 .
# 	Simulation of omega = 1.0200e+00 ends. Total 0.16 s is spent.
# 	Error 9.9486e-22 has been reached, total iterations is 2668 .
# 	Simulation of omega = 1.0300e+00 ends. Total 0.16 s is spent.
# 	Error 9.9986e-22 has been reached, total iterations is 2633 .
# 	Simulation of omega = 1.0400e+00 ends. Total 0.16 s is spent.
# 	Error 9.8591e-22 has been reached, total iterations is 2600 .
# 	Simulation of omega = 1.0500e+00 ends. Total 0.16 s is spent.
# 	Error 9.9550e-22 has been reached, total iterations is 2566 .
# 	Simulation of omega = 1.0600e+00 ends. Total 0.15 s is spent.
# 	Error 9.9994e-22 has been reached, total iterations is 2533 .
# 	Simulation of omega = 1.0700e+00 ends. Total 0.15 s is spent.
# 	Error 9.9868e-22 has been reached, total iterations is 2501 .
# 	Simulation of omega = 1.0800e+00 ends. Total 0.15 s is spent.
# 	Error 9.9130e-22 has been reached, total iterations is 2470 .
# 	Simulation of omega = 1.0900e+00 ends. Total 0.15 s is spent.
# 	Error 9.9259e-22 has been reached, total iterations is 2439 .
# 	Simulation of omega = 1.1000e+00 ends. Total 0.15 s is spent.
# 	Error 9.8717e-22 has been reached, total iterations is 2409 .
# 	Simulation of omega = 1.1100e+00 ends. Total 0.14 s is spent.
# 	Error 9.9021e-22 has been reached, total iterations is 2379 .
# 	Simulation of omega = 1.1200e+00 ends. Total 0.14 s is spent.
# 	Error 9.8588e-22 has been reached, total iterations is 2350 .
# 	Simulation of omega = 1.1300e+00 ends. Total 0.14 s is spent.
# 	Error 9.8982e-22 has been reached, total iterations is 2321 .
# 	Simulation of omega = 1.1400e+00 ends. Total 0.14 s is spent.
# 	Error 9.8581e-22 has been reached, total iterations is 2293 .
# 	Simulation of omega = 1.1500e+00 ends. Total 0.14 s is spent.
# 	Error 9.8980e-22 has been reached, total iterations is 2265 .
# 	Simulation of omega = 1.1600e+00 ends. Total 0.14 s is spent.
# 	Error 9.8525e-22 has been reached, total iterations is 2238 .
# 	Simulation of omega = 1.1700e+00 ends. Total 0.13 s is spent.
# 	Error 9.8846e-22 has been reached, total iterations is 2211 .
# 	Simulation of omega = 1.1800e+00 ends. Total 0.13 s is spent.
# 	Error 9.9953e-22 has been reached, total iterations is 2184 .
# 	Simulation of omega = 1.1900e+00 ends. Total 0.13 s is spent.
# 	Error 9.8401e-22 has been reached, total iterations is 2159 .
# 	Simulation of omega = 1.2000e+00 ends. Total 0.13 s is spent.
# 	Error 9.9310e-22 has been reached, total iterations is 2133 .
# 	Simulation of omega = 1.2100e+00 ends. Total 0.13 s is spent.
# 	Error 9.9222e-22 has been reached, total iterations is 2108 .
# 	Simulation of omega = 1.2200e+00 ends. Total 0.13 s is spent.
# 	Error 9.9872e-22 has been reached, total iterations is 2083 .
# 	Simulation of omega = 1.2300e+00 ends. Total 0.12 s is spent.
# 	Error 9.9451e-22 has been reached, total iterations is 2059 .
# 	Simulation of omega = 1.2400e+00 ends. Total 0.12 s is spent.
# 	Error 9.9740e-22 has been reached, total iterations is 2035 .
# 	Simulation of omega = 1.2500e+00 ends. Total 0.12 s is spent.
# 	Error 9.8886e-22 has been reached, total iterations is 2012 .
# 	Simulation of omega = 1.2600e+00 ends. Total 0.12 s is spent.
# 	Error 9.8719e-22 has been reached, total iterations is 1989 .
# 	Simulation of omega = 1.2700e+00 ends. Total 0.12 s is spent.
# 	Error 9.9236e-22 has been reached, total iterations is 1966 .
# 	Simulation of omega = 1.2800e+00 ends. Total 0.12 s is spent.
# 	Error 9.8534e-22 has been reached, total iterations is 1944 .
# 	Simulation of omega = 1.2900e+00 ends. Total 0.12 s is spent.
# 	Error 9.8488e-22 has been reached, total iterations is 1922 .
# 	Simulation of omega = 1.3000e+00 ends. Total 0.12 s is spent.
# 	Error 9.9105e-22 has been reached, total iterations is 1900 .
# 	Simulation of omega = 1.3100e+00 ends. Total 0.11 s is spent.
# 	Error 9.8412e-22 has been reached, total iterations is 1879 .
# 	Simulation of omega = 1.3200e+00 ends. Total 0.11 s is spent.
# 	Error 9.8360e-22 has been reached, total iterations is 1858 .
# Test the optimal omega for SOR scheme with N=64 .
# 	Simulation of omega = 2.5000e-01 ends. Total 6.75 s is spent.
# 	Error 9.9976e-22 has been reached, total iterations is 52784 .
# 	Simulation of omega = 2.6000e-01 ends. Total 6.49 s is spent.
# 	Error 9.9967e-22 has been reached, total iterations is 50619 .
# 	Simulation of omega = 2.7000e-01 ends. Total 6.22 s is spent.
# 	Error 9.9996e-22 has been reached, total iterations is 48614 .
# 	Simulation of omega = 2.8000e-01 ends. Total 6.01 s is spent.
# 	Error 9.9971e-22 has been reached, total iterations is 46753 .
# 	Simulation of omega = 2.9000e-01 ends. Total 5.76 s is spent.
# 	Error 9.9966e-22 has been reached, total iterations is 45020 .
# 	Simulation of omega = 3.0000e-01 ends. Total 5.60 s is spent.
# 	Error 9.9990e-22 has been reached, total iterations is 43402 .
# 	Simulation of omega = 3.1000e-01 ends. Total 5.37 s is spent.
# 	Error 9.9919e-22 has been reached, total iterations is 41890 .
# 	Simulation of omega = 3.2000e-01 ends. Total 5.21 s is spent.
# 	Error 9.9961e-22 has been reached, total iterations is 40471 .
# 	Simulation of omega = 3.3000e-01 ends. Total 5.02 s is spent.
# 	Error 9.9995e-22 has been reached, total iterations is 39138 .
# 	Simulation of omega = 3.4000e-01 ends. Total 4.87 s is spent.
# 	Error 9.9995e-22 has been reached, total iterations is 37884 .
# 	Simulation of omega = 3.5000e-01 ends. Total 4.70 s is spent.
# 	Error 9.9947e-22 has been reached, total iterations is 36702 .
# 	Simulation of omega = 3.6000e-01 ends. Total 4.58 s is spent.
# 	Error 9.9985e-22 has been reached, total iterations is 35585 .
# 	Simulation of omega = 3.7000e-01 ends. Total 4.43 s is spent.
# 	Error 9.9946e-22 has been reached, total iterations is 34529 .
# 	Simulation of omega = 3.8000e-01 ends. Total 4.31 s is spent.
# 	Error 9.9972e-22 has been reached, total iterations is 33528 .
# 	Simulation of omega = 3.9000e-01 ends. Total 4.17 s is spent.
# 	Error 9.9928e-22 has been reached, total iterations is 32579 .
# 	Simulation of omega = 4.0000e-01 ends. Total 4.07 s is spent.
# 	Error 9.9944e-22 has been reached, total iterations is 31677 .
# 	Simulation of omega = 4.1000e-01 ends. Total 3.94 s is spent.
# 	Error 9.9950e-22 has been reached, total iterations is 30819 .
# 	Simulation of omega = 4.2000e-01 ends. Total 3.86 s is spent.
# 	Error 9.9948e-22 has been reached, total iterations is 30002 .
# 	Simulation of omega = 4.3000e-01 ends. Total 3.74 s is spent.
# 	Error 9.9950e-22 has been reached, total iterations is 29223 .
# 	Simulation of omega = 4.4000e-01 ends. Total 3.66 s is spent.
# 	Error 9.9997e-22 has been reached, total iterations is 28479 .
# 	Simulation of omega = 4.5000e-01 ends. Total 3.55 s is spent.
# 	Error 9.9930e-22 has been reached, total iterations is 27769 .
# 	Simulation of omega = 4.6000e-01 ends. Total 3.49 s is spent.
# 	Error 9.9984e-22 has been reached, total iterations is 27089 .
# 	Simulation of omega = 4.7000e-01 ends. Total 3.39 s is spent.
# 	Error 9.9891e-22 has been reached, total iterations is 26439 .
# 	Simulation of omega = 4.8000e-01 ends. Total 3.31 s is spent.
# 	Error 9.9952e-22 has been reached, total iterations is 25815 .
# 	Simulation of omega = 4.9000e-01 ends. Total 3.23 s is spent.
# 	Error 9.9944e-22 has been reached, total iterations is 25217 .
# 	Simulation of omega = 5.0000e-01 ends. Total 3.16 s is spent.
# 	Error 9.9990e-22 has been reached, total iterations is 24642 .
# 	Simulation of omega = 5.1000e-01 ends. Total 3.07 s is spent.
# 	Error 9.9954e-22 has been reached, total iterations is 24091 .
# 	Simulation of omega = 5.2000e-01 ends. Total 3.03 s is spent.
# 	Error 9.9904e-22 has been reached, total iterations is 23561 .
# 	Simulation of omega = 5.3000e-01 ends. Total 2.93 s is spent.
# 	Error 9.9848e-22 has been reached, total iterations is 23051 .
# 	Simulation of omega = 5.4000e-01 ends. Total 2.91 s is spent.
# 	Error 9.9930e-22 has been reached, total iterations is 22559 .
# 	Simulation of omega = 5.5000e-01 ends. Total 2.83 s is spent.
# 	Error 9.9996e-22 has been reached, total iterations is 22085 .
# 	Simulation of omega = 5.6000e-01 ends. Total 2.78 s is spent.
# 	Error 9.9899e-22 has been reached, total iterations is 21629 .
# 	Simulation of omega = 5.7000e-01 ends. Total 2.71 s is spent.
# 	Error 9.9956e-22 has been reached, total iterations is 21188 .
# 	Simulation of omega = 5.8000e-01 ends. Total 2.67 s is spent.
# 	Error 9.9893e-22 has been reached, total iterations is 20763 .
# 	Simulation of omega = 5.9000e-01 ends. Total 2.60 s is spent.
# 	Error 9.9896e-22 has been reached, total iterations is 20352 .
# 	Simulation of omega = 6.0000e-01 ends. Total 2.57 s is spent.
# 	Error 9.9850e-22 has been reached, total iterations is 19955 .
# 	Simulation of omega = 6.1000e-01 ends. Total 2.51 s is spent.
# 	Error 9.9990e-22 has been reached, total iterations is 19570 .
# 	Simulation of omega = 6.2000e-01 ends. Total 2.47 s is spent.
# 	Error 9.9835e-22 has been reached, total iterations is 19199 .
# 	Simulation of omega = 6.3000e-01 ends. Total 2.41 s is spent.
# 	Error 9.9835e-22 has been reached, total iterations is 18839 .
# 	Simulation of omega = 6.4000e-01 ends. Total 2.38 s is spent.
# 	Error 9.9884e-22 has been reached, total iterations is 18490 .
# 	Simulation of omega = 6.5000e-01 ends. Total 2.32 s is spent.
# 	Error 9.9875e-22 has been reached, total iterations is 18152 .
# 	Simulation of omega = 6.6000e-01 ends. Total 2.29 s is spent.
# 	Error 9.9927e-22 has been reached, total iterations is 17824 .
# 	Simulation of omega = 6.7000e-01 ends. Total 2.23 s is spent.
# 	Error 9.9935e-22 has been reached, total iterations is 17506 .
# 	Simulation of omega = 6.8000e-01 ends. Total 2.21 s is spent.
# 	Error 9.9822e-22 has been reached, total iterations is 17198 .
# 	Simulation of omega = 6.9000e-01 ends. Total 2.16 s is spent.
# 	Error 9.9889e-22 has been reached, total iterations is 16898 .
# 	Simulation of omega = 7.0000e-01 ends. Total 2.13 s is spent.
# 	Error 9.9866e-22 has been reached, total iterations is 16607 .
# 	Simulation of omega = 7.1000e-01 ends. Total 2.09 s is spent.
# 	Error 9.9909e-22 has been reached, total iterations is 16324 .
# 	Simulation of omega = 7.2000e-01 ends. Total 2.06 s is spent.
# 	Error 9.9911e-22 has been reached, total iterations is 16049 .
# 	Simulation of omega = 7.3000e-01 ends. Total 2.02 s is spent.
# 	Error 9.9812e-22 has been reached, total iterations is 15782 .
# 	Simulation of omega = 7.4000e-01 ends. Total 1.99 s is spent.
# 	Error 9.9986e-22 has been reached, total iterations is 15521 .
# 	Simulation of omega = 7.5000e-01 ends. Total 1.95 s is spent.
# 	Error 9.9915e-22 has been reached, total iterations is 15268 .
# 	Simulation of omega = 7.6000e-01 ends. Total 1.93 s is spent.
# 	Error 9.9793e-22 has been reached, total iterations is 15022 .
# 	Simulation of omega = 7.7000e-01 ends. Total 1.89 s is spent.
# 	Error 9.9993e-22 has been reached, total iterations is 14781 .
# 	Simulation of omega = 7.8000e-01 ends. Total 1.87 s is spent.
# 	Error 9.9992e-22 has been reached, total iterations is 14547 .
# 	Simulation of omega = 7.9000e-01 ends. Total 1.83 s is spent.
# 	Error 9.9977e-22 has been reached, total iterations is 14319 .
# 	Simulation of omega = 8.0000e-01 ends. Total 1.82 s is spent.
# 	Error 9.9893e-22 has been reached, total iterations is 14097 .
# 	Simulation of omega = 8.1000e-01 ends. Total 1.77 s is spent.
# 	Error 9.9930e-22 has been reached, total iterations is 13880 .
# 	Simulation of omega = 8.2000e-01 ends. Total 1.76 s is spent.
# 	Error 9.9779e-22 has been reached, total iterations is 13669 .
# 	Simulation of omega = 8.3000e-01 ends. Total 1.72 s is spent.
# 	Error 9.9928e-22 has been reached, total iterations is 13462 .
# 	Simulation of omega = 8.4000e-01 ends. Total 1.70 s is spent.
# 	Error 9.9789e-22 has been reached, total iterations is 13261 .
# 	Simulation of omega = 8.5000e-01 ends. Total 1.67 s is spent.
# 	Error 9.9849e-22 has been reached, total iterations is 13064 .
# 	Simulation of omega = 8.6000e-01 ends. Total 1.66 s is spent.
# 	Error 9.9794e-22 has been reached, total iterations is 12872 .
# 	Simulation of omega = 8.7000e-01 ends. Total 1.62 s is spent.
# 	Error 9.9863e-22 has been reached, total iterations is 12684 .
# 	Simulation of omega = 8.8000e-01 ends. Total 1.60 s is spent.
# 	Error 9.9724e-22 has been reached, total iterations is 12501 .
# 	Simulation of omega = 8.9000e-01 ends. Total 1.57 s is spent.
# 	Error 9.9902e-22 has been reached, total iterations is 12321 .
# 	Simulation of omega = 9.0000e-01 ends. Total 1.56 s is spent.
# 	Error 9.9796e-22 has been reached, total iterations is 12146 .
# 	Simulation of omega = 9.1000e-01 ends. Total 1.53 s is spent.
# 	Error 9.9945e-22 has been reached, total iterations is 11974 .
# 	Simulation of omega = 9.2000e-01 ends. Total 1.52 s is spent.
# 	Error 9.9722e-22 has been reached, total iterations is 11807 .
# 	Simulation of omega = 9.3000e-01 ends. Total 1.49 s is spent.
# 	Error 9.9975e-22 has been reached, total iterations is 11642 .
# 	Simulation of omega = 9.4000e-01 ends. Total 1.48 s is spent.
# 	Error 9.9780e-22 has been reached, total iterations is 11482 .
# 	Simulation of omega = 9.5000e-01 ends. Total 1.45 s is spent.
# 	Error 9.9700e-22 has been reached, total iterations is 11325 .
# 	Simulation of omega = 9.6000e-01 ends. Total 1.44 s is spent.
# 	Error 9.9708e-22 has been reached, total iterations is 11171 .
# 	Simulation of omega = 9.7000e-01 ends. Total 1.40 s is spent.
# 	Error 9.9776e-22 has been reached, total iterations is 11020 .
# 	Simulation of omega = 9.8000e-01 ends. Total 1.39 s is spent.
# 	Error 9.9868e-22 has been reached, total iterations is 10872 .
# 	Simulation of omega = 9.9000e-01 ends. Total 1.37 s is spent.
# 	Error 9.9966e-22 has been reached, total iterations is 10727 .
# 	Simulation of omega = 1.0000e+00 ends. Total 1.36 s is spent.
# 	Error 9.9700e-22 has been reached, total iterations is 10586 .
# 	Simulation of omega = 1.0100e+00 ends. Total 1.33 s is spent.
# 	Error 9.9709e-22 has been reached, total iterations is 10447 .
# 	Simulation of omega = 1.0200e+00 ends. Total 1.32 s is spent.
# 	Error 9.9958e-22 has been reached, total iterations is 10310 .
# 	Simulation of omega = 1.0300e+00 ends. Total 1.30 s is spent.
# 	Error 9.9749e-22 has been reached, total iterations is 10177 .
# 	Simulation of omega = 1.0400e+00 ends. Total 1.29 s is spent.
# 	Error 9.9739e-22 has been reached, total iterations is 10046 .
# 	Simulation of omega = 1.0500e+00 ends. Total 1.27 s is spent.
# 	Error 9.9901e-22 has been reached, total iterations is 9917 .
# 	Simulation of omega = 1.0600e+00 ends. Total 1.26 s is spent.
# 	Error 9.9878e-22 has been reached, total iterations is 9791 .
# 	Simulation of omega = 1.0700e+00 ends. Total 1.24 s is spent.
# 	Error 9.9981e-22 has been reached, total iterations is 9667 .
# 	Simulation of omega = 1.0800e+00 ends. Total 1.22 s is spent.
# 	Error 9.9821e-22 has been reached, total iterations is 9546 .
# 	Simulation of omega = 1.0900e+00 ends. Total 1.21 s is spent.
# 	Error 9.9750e-22 has been reached, total iterations is 9427 .
# 	Simulation of omega = 1.1000e+00 ends. Total 1.19 s is spent.
# 	Error 9.9733e-22 has been reached, total iterations is 9310 .
# 	Simulation of omega = 1.1100e+00 ends. Total 1.17 s is spent.
# 	Error 9.9775e-22 has been reached, total iterations is 9195 .
# 	Simulation of omega = 1.1200e+00 ends. Total 1.17 s is spent.
# 	Error 9.9838e-22 has been reached, total iterations is 9082 .
# 	Simulation of omega = 1.1300e+00 ends. Total 1.15 s is spent.
# 	Error 9.9901e-22 has been reached, total iterations is 8971 .
# 	Simulation of omega = 1.1400e+00 ends. Total 1.14 s is spent.
# 	Error 9.9944e-22 has been reached, total iterations is 8862 .
# 	Simulation of omega = 1.1500e+00 ends. Total 1.12 s is spent.
# 	Error 9.9953e-22 has been reached, total iterations is 8755 .
# 	Simulation of omega = 1.1600e+00 ends. Total 1.11 s is spent.
# 	Error 9.9902e-22 has been reached, total iterations is 8650 .
# 	Simulation of omega = 1.1700e+00 ends. Total 1.09 s is spent.
# 	Error 9.9761e-22 has been reached, total iterations is 8547 .
# 	Simulation of omega = 1.1800e+00 ends. Total 1.09 s is spent.
# 	Error 9.9946e-22 has been reached, total iterations is 8445 .
# 	Simulation of omega = 1.1900e+00 ends. Total 1.07 s is spent.
# 	Error 9.9583e-22 has been reached, total iterations is 8346 .
# 	Simulation of omega = 1.2000e+00 ends. Total 1.06 s is spent.
# 	Error 9.9928e-22 has been reached, total iterations is 8247 .
# 	Simulation of omega = 1.2100e+00 ends. Total 1.04 s is spent.
# 	Error 9.9687e-22 has been reached, total iterations is 8151 .
# 	Simulation of omega = 1.2200e+00 ends. Total 1.03 s is spent.
# 	Error 9.9696e-22 has been reached, total iterations is 8056 .
# 	Simulation of omega = 1.2300e+00 ends. Total 1.02 s is spent.
# 	Error 9.9958e-22 has been reached, total iterations is 7962 .
# 	Simulation of omega = 1.2400e+00 ends. Total 1.01 s is spent.
# 	Error 9.9560e-22 has been reached, total iterations is 7871 .
# 	Simulation of omega = 1.2500e+00 ends. Total 1.00 s is spent.
# 	Error 9.9799e-22 has been reached, total iterations is 7780 .
# 	Simulation of omega = 1.2600e+00 ends. Total 1.00 s is spent.
# 	Error 9.9813e-22 has been reached, total iterations is 7691 .
# 	Simulation of omega = 1.2700e+00 ends. Total 0.97 s is spent.
# 	Error 9.9547e-22 has been reached, total iterations is 7604 .
# 	Simulation of omega = 1.2800e+00 ends. Total 0.97 s is spent.
# 	Error 9.9919e-22 has been reached, total iterations is 7517 .
# 	Simulation of omega = 1.2900e+00 ends. Total 0.95 s is spent.
# 	Error 9.9985e-22 has been reached, total iterations is 7432 .
# 	Simulation of omega = 1.3000e+00 ends. Total 0.95 s is spent.
# 	Error 9.9727e-22 has been reached, total iterations is 7349 .
# 	Simulation of omega = 1.3100e+00 ends. Total 0.93 s is spent.
# 	Error 9.9602e-22 has been reached, total iterations is 7267 .
# 	Simulation of omega = 1.3200e+00 ends. Total 0.92 s is spent.
# 	Error 9.9590e-22 has been reached, total iterations is 7186 .
# Test the optimal omega for SOR scheme with N=128 .
# 	Simulation of omega = 2.5000e-01 ends. Total 80.21 s is spent.
# 	Error 9.9980e-22 has been reached, total iterations is 203460 .
# 	Simulation of omega = 2.6000e-01 ends. Total 76.94 s is spent.
# 	Error 9.9996e-22 has been reached, total iterations is 195098 .
# 	Simulation of omega = 2.7000e-01 ends. Total 73.92 s is spent.
# 	Error 9.9986e-22 has been reached, total iterations is 187372 .
# 	Simulation of omega = 2.8000e-01 ends. Total 71.01 s is spent.
# 	Error 9.9980e-22 has been reached, total iterations is 180199 .
# 	Simulation of omega = 2.9000e-01 ends. Total 68.39 s is spent.
# 	Error 9.9998e-22 has been reached, total iterations is 173520 .
# 	Simulation of omega = 3.0000e-01 ends. Total 65.91 s is spent.
# 	Error 9.9994e-22 has been reached, total iterations is 167282 .
# 	Simulation of omega = 3.1000e-01 ends. Total 63.69 s is spent.
# 	Error 9.9995e-22 has been reached, total iterations is 161454 .
# 	Simulation of omega = 3.2000e-01 ends. Total 61.54 s is spent.
# 	Error 9.9988e-22 has been reached, total iterations is 155987 .
# 	Simulation of omega = 3.3000e-01 ends. Total 59.48 s is spent.
# 	Error 9.9977e-22 has been reached, total iterations is 150851 .
# 	Simulation of omega = 3.4000e-01 ends. Total 57.62 s is spent.
# 	Error 9.9976e-22 has been reached, total iterations is 146019 .
# 	Simulation of omega = 3.5000e-01 ends. Total 55.77 s is spent.
# 	Error 9.9991e-22 has been reached, total iterations is 141460 .
# 	Simulation of omega = 3.6000e-01 ends. Total 54.08 s is spent.
# 	Error 9.9996e-22 has been reached, total iterations is 137157 .
# 	Simulation of omega = 3.7000e-01 ends. Total 52.50 s is spent.
# 	Error 9.9995e-22 has been reached, total iterations is 133087 .
# 	Simulation of omega = 3.8000e-01 ends. Total 50.91 s is spent.
# 	Error 9.9979e-22 has been reached, total iterations is 129229 .
# 	Simulation of omega = 3.9000e-01 ends. Total 49.49 s is spent.
# 	Error 9.9983e-22 has been reached, total iterations is 125570 .
# 	Simulation of omega = 4.0000e-01 ends. Total 48.12 s is spent.
# 	Error 9.9987e-22 has been reached, total iterations is 122094 .
# 	Simulation of omega = 4.1000e-01 ends. Total 46.80 s is spent.
# 	Error 9.9967e-22 has been reached, total iterations is 118788 .
# 	Simulation of omega = 4.2000e-01 ends. Total 45.60 s is spent.
# 	Error 9.9976e-22 has been reached, total iterations is 115639 .
# 	Simulation of omega = 4.3000e-01 ends. Total 44.33 s is spent.
# 	Error 9.9990e-22 has been reached, total iterations is 112637 .
# 	Simulation of omega = 4.4000e-01 ends. Total 43.29 s is spent.
# 	Error 9.9990e-22 has been reached, total iterations is 109771 .
# 	Simulation of omega = 4.5000e-01 ends. Total 42.15 s is spent.
# 	Error 9.9968e-22 has been reached, total iterations is 107033 .
# 	Simulation of omega = 4.6000e-01 ends. Total 41.14 s is spent.
# 	Error 9.9988e-22 has been reached, total iterations is 104413 .
# 	Simulation of omega = 4.7000e-01 ends. Total 40.17 s is spent.
# 	Error 9.9993e-22 has been reached, total iterations is 101906 .
# 	Simulation of omega = 4.8000e-01 ends. Total 39.21 s is spent.
# 	Error 9.9962e-22 has been reached, total iterations is 99504 .
# 	Simulation of omega = 4.9000e-01 ends. Total 38.33 s is spent.
# 	Error 9.9957e-22 has been reached, total iterations is 97200 .
# 	Simulation of omega = 5.0000e-01 ends. Total 37.42 s is spent.
# 	Error 9.9985e-22 has been reached, total iterations is 94976 .
# 	Simulation of omega = 5.1000e-01 ends. Total 36.58 s is spent.
# 	Error 9.9999e-22 has been reached, total iterations is 92854 .
# 	Simulation of omega = 5.2000e-01 ends. Total 35.78 s is spent.
# 	Error 9.9993e-22 has been reached, total iterations is 90811 .
# 	Simulation of omega = 5.3000e-01 ends. Total 35.03 s is spent.
# 	Error 9.9983e-22 has been reached, total iterations is 88845 .
# 	Simulation of omega = 5.4000e-01 ends. Total 34.22 s is spent.
# 	Error 9.9979e-22 has been reached, total iterations is 86951 .
# 	Simulation of omega = 5.5000e-01 ends. Total 33.54 s is spent.
# 	Error 9.9997e-22 has been reached, total iterations is 85125 .
# 	Simulation of omega = 5.6000e-01 ends. Total 32.80 s is spent.
# 	Error 9.9986e-22 has been reached, total iterations is 83366 .
# 	Simulation of omega = 5.7000e-01 ends. Total 32.14 s is spent.
# 	Error 9.9989e-22 has been reached, total iterations is 81668 .
# 	Simulation of omega = 5.8000e-01 ends. Total 31.52 s is spent.
# 	Error 9.9981e-22 has been reached, total iterations is 80029 .
# 	Simulation of omega = 5.9000e-01 ends. Total 30.90 s is spent.
# 	Error 9.9986e-22 has been reached, total iterations is 78445 .
# 	Simulation of omega = 6.0000e-01 ends. Total 30.28 s is spent.
# 	Error 9.9955e-22 has been reached, total iterations is 76915 .
# 	Simulation of omega = 6.1000e-01 ends. Total 29.73 s is spent.
# 	Error 9.9968e-22 has been reached, total iterations is 75434 .
# 	Simulation of omega = 6.2000e-01 ends. Total 29.16 s is spent.
# 	Error 9.9975e-22 has been reached, total iterations is 74001 .
# 	Simulation of omega = 6.3000e-01 ends. Total 28.57 s is spent.
# 	Error 9.9985e-22 has been reached, total iterations is 72613 .
# 	Simulation of omega = 6.4000e-01 ends. Total 28.05 s is spent.
# 	Error 9.9959e-22 has been reached, total iterations is 71270 .
# 	Simulation of omega = 6.5000e-01 ends. Total 27.55 s is spent.
# 	Error 9.9960e-22 has been reached, total iterations is 69967 .
# 	Simulation of omega = 6.6000e-01 ends. Total 27.05 s is spent.
# 	Error 9.9958e-22 has been reached, total iterations is 68704 .
# 	Simulation of omega = 6.7000e-01 ends. Total 26.57 s is spent.
# 	Error 9.9978e-22 has been reached, total iterations is 67479 .
# 	Simulation of omega = 6.8000e-01 ends. Total 26.14 s is spent.
# 	Error 9.9961e-22 has been reached, total iterations is 66290 .
# 	Simulation of omega = 6.9000e-01 ends. Total 25.66 s is spent.
# 	Error 9.9973e-22 has been reached, total iterations is 65135 .
# 	Simulation of omega = 7.0000e-01 ends. Total 25.20 s is spent.
# 	Error 9.9966e-22 has been reached, total iterations is 64013 .
# 	Simulation of omega = 7.1000e-01 ends. Total 24.80 s is spent.
# 	Error 9.9992e-22 has been reached, total iterations is 62923 .
# 	Simulation of omega = 7.2000e-01 ends. Total 24.34 s is spent.
# 	Error 9.9966e-22 has been reached, total iterations is 61864 .
# 	Simulation of omega = 7.3000e-01 ends. Total 23.96 s is spent.
# 	Error 9.9987e-22 has been reached, total iterations is 60833 .
# 	Simulation of omega = 7.4000e-01 ends. Total 23.56 s is spent.
# 	Error 9.9942e-22 has been reached, total iterations is 59831 .
# 	Simulation of omega = 7.5000e-01 ends. Total 23.18 s is spent.
# 	Error 9.9978e-22 has been reached, total iterations is 58853 .
# 	Simulation of omega = 7.6000e-01 ends. Total 22.80 s is spent.
# 	Error 9.9967e-22 has been reached, total iterations is 57904 .
# 	Simulation of omega = 7.7000e-01 ends. Total 22.44 s is spent.
# 	Error 9.9946e-22 has been reached, total iterations is 56979 .
# 	Simulation of omega = 7.8000e-01 ends. Total 22.06 s is spent.
# 	Error 9.9968e-22 has been reached, total iterations is 56077 .
# 	Simulation of omega = 7.9000e-01 ends. Total 21.73 s is spent.
# 	Error 9.9979e-22 has been reached, total iterations is 55198 .
# 	Simulation of omega = 8.0000e-01 ends. Total 21.39 s is spent.
# 	Error 9.9989e-22 has been reached, total iterations is 54341 .
# 	Simulation of omega = 8.1000e-01 ends. Total 21.07 s is spent.
# 	Error 9.9963e-22 has been reached, total iterations is 53506 .
# 	Simulation of omega = 8.2000e-01 ends. Total 20.74 s is spent.
# 	Error 1.0000e-21 has been reached, total iterations is 52690 .
# 	Simulation of omega = 8.3000e-01 ends. Total 20.45 s is spent.
# 	Error 9.9977e-22 has been reached, total iterations is 51895 .
# 	Simulation of omega = 8.4000e-01 ends. Total 20.14 s is spent.
# 	Error 9.9992e-22 has been reached, total iterations is 51118 .
# 	Simulation of omega = 8.5000e-01 ends. Total 19.84 s is spent.
# 	Error 9.9958e-22 has been reached, total iterations is 50360 .
# 	Simulation of omega = 8.6000e-01 ends. Total 19.54 s is spent.
# 	Error 9.9947e-22 has been reached, total iterations is 49620 .
# 	Simulation of omega = 8.7000e-01 ends. Total 19.28 s is spent.
# 	Error 9.9977e-22 has been reached, total iterations is 48896 .
# 	Simulation of omega = 8.8000e-01 ends. Total 18.99 s is spent.
# 	Error 9.9949e-22 has been reached, total iterations is 48189 .
# 	Simulation of omega = 8.9000e-01 ends. Total 18.69 s is spent.
# 	Error 9.9955e-22 has been reached, total iterations is 47498 .
# 	Simulation of omega = 9.0000e-01 ends. Total 18.47 s is spent.
# 	Error 9.9956e-22 has been reached, total iterations is 46822 .
# 	Simulation of omega = 9.1000e-01 ends. Total 18.18 s is spent.
# 	Error 9.9994e-22 has been reached, total iterations is 46161 .
# 	Simulation of omega = 9.2000e-01 ends. Total 17.92 s is spent.
# 	Error 9.9954e-22 has been reached, total iterations is 45515 .
# 	Simulation of omega = 9.3000e-01 ends. Total 17.68 s is spent.
# 	Error 9.9996e-22 has been reached, total iterations is 44882 .
# 	Simulation of omega = 9.4000e-01 ends. Total 17.44 s is spent.
# 	Error 9.9999e-22 has been reached, total iterations is 44263 .
# 	Simulation of omega = 9.5000e-01 ends. Total 17.22 s is spent.
# 	Error 9.9993e-22 has been reached, total iterations is 43657 .
# 	Simulation of omega = 9.6000e-01 ends. Total 16.95 s is spent.
# 	Error 9.9979e-22 has been reached, total iterations is 43064 .
# 	Simulation of omega = 9.7000e-01 ends. Total 16.76 s is spent.
# 	Error 9.9977e-22 has been reached, total iterations is 42483 .
# 	Simulation of omega = 9.8000e-01 ends. Total 16.52 s is spent.
# 	Error 9.9959e-22 has been reached, total iterations is 41914 .
# 	Simulation of omega = 9.9000e-01 ends. Total 16.29 s is spent.
# 	Error 9.9994e-22 has been reached, total iterations is 41356 .
# 	Simulation of omega = 1.0000e+00 ends. Total 16.07 s is spent.
# 	Error 9.9986e-22 has been reached, total iterations is 40810 .
# 	Simulation of omega = 1.0100e+00 ends. Total 15.87 s is spent.
# 	Error 9.9972e-22 has been reached, total iterations is 40275 .
# 	Simulation of omega = 1.0200e+00 ends. Total 15.66 s is spent.
# 	Error 9.9964e-22 has been reached, total iterations is 39750 .
# 	Simulation of omega = 1.0300e+00 ends. Total 15.45 s is spent.
# 	Error 9.9986e-22 has been reached, total iterations is 39235 .
# 	Simulation of omega = 1.0400e+00 ends. Total 15.25 s is spent.
# 	Error 9.9922e-22 has been reached, total iterations is 38731 .
# 	Simulation of omega = 1.0500e+00 ends. Total 15.05 s is spent.
# 	Error 9.9973e-22 has been reached, total iterations is 38235 .
# 	Simulation of omega = 1.0600e+00 ends. Total 14.85 s is spent.
# 	Error 9.9908e-22 has been reached, total iterations is 37750 .
# 	Simulation of omega = 1.0700e+00 ends. Total 14.68 s is spent.
# 	Error 9.9944e-22 has been reached, total iterations is 37273 .
# 	Simulation of omega = 1.0800e+00 ends. Total 14.49 s is spent.
# 	Error 9.9950e-22 has been reached, total iterations is 36805 .
# 	Simulation of omega = 1.0900e+00 ends. Total 14.31 s is spent.
# 	Error 9.9922e-22 has been reached, total iterations is 36346 .
# 	Simulation of omega = 1.1000e+00 ends. Total 14.15 s is spent.
# 	Error 9.9922e-22 has been reached, total iterations is 35895 .
# 	Simulation of omega = 1.1100e+00 ends. Total 13.96 s is spent.
# 	Error 9.9972e-22 has been reached, total iterations is 35452 .
# 	Simulation of omega = 1.1200e+00 ends. Total 13.78 s is spent.
# 	Error 9.9916e-22 has been reached, total iterations is 35018 .
# 	Simulation of omega = 1.1300e+00 ends. Total 13.62 s is spent.
# 	Error 9.9910e-22 has been reached, total iterations is 34591 .
# 	Simulation of omega = 1.1400e+00 ends. Total 13.47 s is spent.
# 	Error 9.9950e-22 has been reached, total iterations is 34171 .
# 	Simulation of omega = 1.1500e+00 ends. Total 13.30 s is spent.
# 	Error 9.9937e-22 has been reached, total iterations is 33759 .
# 	Simulation of omega = 1.1600e+00 ends. Total 13.14 s is spent.
# 	Error 9.9943e-22 has been reached, total iterations is 33354 .
# 	Simulation of omega = 1.1700e+00 ends. Total 12.99 s is spent.
# 	Error 9.9910e-22 has been reached, total iterations is 32956 .
# 	Simulation of omega = 1.1800e+00 ends. Total 12.83 s is spent.
# 	Error 9.9997e-22 has been reached, total iterations is 32564 .
# 	Simulation of omega = 1.1900e+00 ends. Total 12.69 s is spent.
# 	Error 9.9914e-22 has been reached, total iterations is 32180 .
# 	Simulation of omega = 1.2000e+00 ends. Total 12.53 s is spent.
# 	Error 9.9898e-22 has been reached, total iterations is 31802 .
# 	Simulation of omega = 1.2100e+00 ends. Total 12.38 s is spent.
# 	Error 9.9900e-22 has been reached, total iterations is 31430 .
# 	Simulation of omega = 1.2200e+00 ends. Total 12.25 s is spent.
# 	Error 9.9909e-22 has been reached, total iterations is 31064 .
# 	Simulation of omega = 1.2300e+00 ends. Total 12.09 s is spent.
# 	Error 9.9934e-22 has been reached, total iterations is 30704 .
# 	Simulation of omega = 1.2400e+00 ends. Total 11.97 s is spent.
# 	Error 9.9939e-22 has been reached, total iterations is 30350 .
# 	Simulation of omega = 1.2500e+00 ends. Total 11.81 s is spent.
# 	Error 9.9912e-22 has been reached, total iterations is 30002 .
# 	Simulation of omega = 1.2600e+00 ends. Total 11.68 s is spent.
# 	Error 9.9976e-22 has been reached, total iterations is 29659 .
# 	Simulation of omega = 1.2700e+00 ends. Total 11.56 s is spent.
# 	Error 9.9952e-22 has been reached, total iterations is 29322 .
# 	Simulation of omega = 1.2800e+00 ends. Total 11.41 s is spent.
# 	Error 9.9979e-22 has been reached, total iterations is 28990 .
# 	Simulation of omega = 1.2900e+00 ends. Total 11.30 s is spent.
# 	Error 9.9955e-22 has been reached, total iterations is 28663 .
# 	Simulation of omega = 1.3000e+00 ends. Total 11.17 s is spent.
# 	Error 9.9921e-22 has been reached, total iterations is 28342 .
# 	Simulation of omega = 1.3100e+00 ends. Total 11.03 s is spent.
# 	Error 9.9929e-22 has been reached, total iterations is 28025 .
# 	Simulation of omega = 1.3200e+00 ends. Total 10.93 s is spent.
# 	Error 9.9926e-22 has been reached, total iterations is 27714 .
# Test the optimal omega for SOR scheme with N=256 .

# %%
N_list = []
data_list = []
path = './Optimal_Omega_Test_Fixed_Boundary_L=1/'
files = os.listdir(path)

for file in files:
    if '.txt' in file and '1.00000000e-21' in file:
        data = np.loadtxt('%s%s'%(path, file))
        omega_range, iteration_record, error_record, total_time_record = data[:,0], data[:,1], data[:,2], data[:,3]
        criteria = eval(file.split('_')[1].split('=')[-1])
        lattice_size = eval(file.split('_')[0].split('=')[-1])
        data = np.vstack((omega_range[error_record<criteria], iteration_record[error_record<criteria], \
                          total_time_record[error_record<criteria])).T
        N_list.append(lattice_size)
        data_list.append(data)
dict_data = dict(zip(N_list, data_list))

fig = plt.figure(figsize=(2*3,3), dpi=200)
plt.subplots_adjust(wspace=0.4)
ax_1 = plt.subplot(121)
ax_2 = plt.subplot(122)
for N in sorted(list(dict_data.keys())):
    data = dict_data[N]
    ax_1.semilogy(data[:,0], data[:,1], lw=0.0, marker='o', markersize=2.0, label='N=%d'%N)
    ax_2.semilogy(data[:,0], data[:,2], lw=0.0, marker='o', markersize=2.0, label='N=%d'%N)
    
ax_1.set_xlabel('$\omega$', fontsize=8.)
ax_1.set_ylabel('# of Iterations for Convergence')
ax_1.set_title('# of Iterations v.s $\omega$',y=1.03)
ax_1.set_xticks(np.arange(0.0,1.5,0.25))
ax_1.set_xlim([0.25,1.3])
ax_1.legend(loc='upper right', prop={'size':5.0})
ax_2.set_xlabel('$\omega$', fontsize=8.)
ax_2.set_ylabel('Total Simulation Time (s)')
ax_2.set_title('Total Simuation Time v.s $\omega$',y=1.03)
ax_2.set_xticks(np.arange(0.0,1.5,0.25))
ax_2.set_xlim([0.25,1.3])
ax_2.set_ylim([0.01,160])
ax_2.legend(loc='upper right', prop={'size':5.0})
plt.savefig("/home/lab/Guan_Ming/Computational_Astrophysics/Homework/HW3/Problem_2_Optimal_omega_Fixed_Boundary.png", bbox_inches='tight', dpi=200, pad_inches=0.05)
plt.show()

# %%
fig = plt.figure(figsize=(2*3,3), dpi=200)
plt.subplots_adjust(wspace=0.4)
ax_1 = plt.subplot(121)
ax_2 = plt.subplot(122)

reference_omega = (dict_data[16][:,0]>=0.25) & (dict_data[16][:,0]<=1.3)
reference_iteration = dict_data[16][reference_omega,1]
reference_time = dict_data[16][reference_omega,2]

for N in [16, 32, 64, 128]:
    data = dict_data[N]
    omega_range = (data[:,0]>=0.25) & (data[:,0]<=1.3)
    ax_1.plot(data[omega_range,0], np.log2(data[omega_range,1]/reference_iteration),\
              lw=0.0, marker='o', markersize=2.0, label='N=%d'%N)
    ax_2.plot(data[omega_range,0], np.log2(data[omega_range,2]/reference_time),\
              lw=0.0, marker='o', markersize=2.0, label='N=%d'%N)
    
ax_1.set_xlabel('$\omega$', fontsize=8.)
ax_1.set_ylabel('$log_2$ Iterations')
ax_1.set_title('$log_2$ Iterations v.s $\omega$\n($N=16$ as reference)',y=1.03)
ax_1.set_xticks(np.arange(0.0,1.5,0.25))
ax_1.set_xlim([0.55,1.25])
ax_1.set_ylim([-0.5,6.2])
ax_1.legend(loc='upper right', prop={'size':5.0})
ax_2.set_xlabel('$\omega$', fontsize=8.)
ax_2.set_ylabel('$log_2$ Simulation Time')
ax_2.set_title('$log_2$ Simuation Time v.s $\omega$\n($N=16$ as reference)',y=1.03)
ax_2.set_xticks(np.arange(0.0,1.5,0.25))
ax_2.set_yticks(np.arange(0.0,11,1.0))
ax_2.set_xlim([0.55,1.25])
ax_2.set_ylim([-0.5,10.])
ax_2.legend(loc='upper right', prop={'size':5.0})
plt.show()
