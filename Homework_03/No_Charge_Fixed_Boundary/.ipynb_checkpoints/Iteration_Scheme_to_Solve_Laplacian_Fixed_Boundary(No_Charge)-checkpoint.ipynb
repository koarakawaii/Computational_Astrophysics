# %%
import time, os, math
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from scipy.optimize import curve_fit

# %% [markdown]
# ### Functions

# %%
def LAPLACIAN_JACOBI(phi_old, source, neighbor_r, neighbor_l, neighbor_u, neighbor_d, idx):
    return 0.25*(phi_old[neighbor_r[idx]]+phi_old[neighbor_l[idx]]+phi_old[neighbor_u[idx]]+phi_old[neighbor_d[idx]]\
                 -dx**2*source[idx])
    
def LAPLACIAN_GAUSS_SEIDEL(phi_old, source, neighbor_r, neighbor_l, neighbor_u, neighbor_d, idx_even, idx_odd):
    phi_old[idx_even] = 0.25*(phi_old[neighbor_r[idx_even]]+phi_old[neighbor_l[idx_even]]\
                              +phi_old[neighbor_u[idx_even]]+phi_old[neighbor_d[idx_even]]-dx**2*source[idx_even])
    phi_old[idx_odd] = 0.25*(phi_old[neighbor_r[idx_odd]]+phi_old[neighbor_l[idx_odd]]\
                             +phi_old[neighbor_u[idx_odd]]+phi_old[neighbor_d[idx_odd]]-dx**2*source[idx_odd])
    return phi_old

def LAPLACIAN_SUCCESSIVE_OVER_RELAXATION(phi_old, omega, source, neighbor_r, neighbor_l, neighbor_u, neighbor_d, idx_even, idx_odd):
    phi_old[idx_even] += 0.25*omega*(phi_old[neighbor_r[idx_even]]+phi_old[neighbor_l[idx_even]]+phi_old[neighbor_u[idx_even]]\
                                     +phi_old[neighbor_d[idx_even]]-dx**2*source[idx_even]-4.*phi_old[idx_even])
    phi_old[idx_odd] += 0.25*omega*(phi_old[neighbor_r[idx_odd]]+phi_old[neighbor_l[idx_odd]]+phi_old[neighbor_u[idx_odd]]\
                                     +phi_old[neighbor_d[idx_odd]]-dx**2*source[idx_odd]-4.*phi_old[idx_odd])
    return phi_old
    
def CALCULATE_CRITERIA(phi, source, neighbor_r, neighbor_l, neighbor_u, neighbor_d):
    diff = (1./dx**2*(phi[neighbor_r]+phi[neighbor_l]+phi[neighbor_u]+phi[neighbor_d]-4.*phi)-source)[boundary==False]
    return (diff**2).mean()

def CHECKER_BOARD(N):
    A = np.arange(N*N//2)
    X = (2*A)%N
    Y = (2*A)//N
    P = (X+Y+1)%2
    X += P
    ODD_INDEX = (X + Y*N).copy()
    ODD_INDEX = ODD_INDEX[((ODD_INDEX//N!=N-1)&(ODD_INDEX//N!=0)&(ODD_INDEX%N!=N-1)&(ODD_INDEX%N!=0))]
    
    X = (2*A)%N
    Y = (2*A)//N
    P = (X+Y)%2
    X += P
    EVEN_INDEX = (X + Y*N).copy()
    EVEN_INDEX = EVEN_INDEX[((EVEN_INDEX//N!=N-1)&(EVEN_INDEX//N!=0)&(EVEN_INDEX%N!=N-1)&(EVEN_INDEX%N!=0))]
    return EVEN_INDEX, ODD_INDEX

def linear_fit(x, a, b):
    return a*x+b

# %% [markdown]
# ### Proto-code

# %%
L = 1.0
N = 256
k = 2.0*np.pi/N
x = np.arange(0,N)
y = np.arange(0,N)
xx,yy= np.meshgrid(x,y)

phi_analytic = np.exp(-k*xx)*np.sin(k*yy)

phi = np.zeros(N*N)
rho = np.zeros(N*N)
boundary = ((yy%N==0) | (yy%N==N-1) | (xx%N==0) | (xx%N==N-1)).ravel()
phi[boundary] = phi_analytic.ravel()[boundary]
iteration = 0
iteration_max = 4000000
dx = L/(N-1)
show_error_interval = 100
# mode = 'jacobi'
# mode = 'gauss_seidel'
mode = 'SOR'

neighbor_r = np.arange(N*N)
neighbor_l = np.arange(N*N)
neighbor_u = np.arange(N*N)
neighbor_d = np.arange(N*N)
neighbor_r = N*(neighbor_r//N) + (neighbor_r%N+1)%N
neighbor_l = N*(neighbor_l//N) + (neighbor_l%N+N-1)%N
neighbor_u = N*((neighbor_u//N+1)%N) + neighbor_u%N
neighbor_d = N*((neighbor_d//N+N-1)%N) + neighbor_d%N

# criteria = CALCULATE_CRITERIA(phi_analytic.ravel(), rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)
criteria = 1e-21
error = CALCULATE_CRITERIA(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)
print("Lattice size = %d using %s scheme:"%(N, mode))
if mode=='jacobi':
    phi_copy = phi.copy()
    flag = True
    idx_not_boundary = np.argwhere(boundary==False).reshape(-1)
elif mode=='gauss_seidel' or mode=='SOR':
    idx_even, idx_odd = CHECKER_BOARD(N)
    if mode == 'SOR':
        omega = 1.937
start = time.time()
while error>criteria and iteration<iteration_max:
    if mode=='jacobi':
        if flag:
            phi_copy[boundary==False] = LAPLACIAN_JACOBI(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d, idx_not_boundary)
            error = CALCULATE_CRITERIA(phi_copy, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)
        else:
            phi[boundary==False] = LAPLACIAN_JACOBI(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d, idx_not_boundary)
            error = CALCULATE_CRITERIA(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)
        flag = not flag
    elif mode=='gauss_seidel':
        phi = LAPLACIAN_GAUSS_SEIDEL(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d, idx_even, idx_odd)
        error = CALCULATE_CRITERIA(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)
    else:
        phi = LAPLACIAN_SUCCESSIVE_OVER_RELAXATION(phi, omega, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d, idx_even, idx_odd)
        error = CALCULATE_CRITERIA(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)
    iteration += 1
    if iteration%show_error_interval == 0:
        print("Iteration = %d, error = %.4e , criteria = %.4e ."%(iteration, error, criteria))
if mode=='jacobi':
    if flag:
        phi = phi.copy()
end = time.time()

print("Simulation of %s scheme ends. Total %.2f s is spent."%(mode, end-start))
print("Error %.4e has been reached, total iterations is %d ."%(error, iteration))
print("Error with analytic solution is %.8e ."%(((phi-phi_analytic.ravel())**2).mean())**0.5)
phi = np.array(phi.reshape(N,N))
# Out:
# Lattice size = 256 using SOR scheme:
# Iteration = 100, error = 2.2458e+03 , criteria = 1.0000e-21 .
# Iteration = 200, error = 9.4645e+01 , criteria = 1.0000e-21 .
# Iteration = 300, error = 6.4141e+00 , criteria = 1.0000e-21 .
# Iteration = 400, error = 4.7398e-01 , criteria = 1.0000e-21 .
# Iteration = 500, error = 3.5743e-02 , criteria = 1.0000e-21 .
# Iteration = 600, error = 2.7954e-03 , criteria = 1.0000e-21 .
# Iteration = 700, error = 2.5430e-04 , criteria = 1.0000e-21 .
# Iteration = 800, error = 3.6071e-05 , criteria = 1.0000e-21 .
# Iteration = 900, error = 9.1576e-06 , criteria = 1.0000e-21 .
# Iteration = 1000, error = 3.1345e-06 , criteria = 1.0000e-21 .
# Iteration = 1100, error = 1.1635e-06 , criteria = 1.0000e-21 .
# Iteration = 1200, error = 4.3940e-07 , criteria = 1.0000e-21 .
# Iteration = 1300, error = 1.6652e-07 , criteria = 1.0000e-21 .
# Iteration = 1400, error = 6.3149e-08 , criteria = 1.0000e-21 .
# Iteration = 1500, error = 2.3951e-08 , criteria = 1.0000e-21 .
# Iteration = 1600, error = 9.0845e-09 , criteria = 1.0000e-21 .
# Iteration = 1700, error = 3.4457e-09 , criteria = 1.0000e-21 .
# Iteration = 1800, error = 1.3069e-09 , criteria = 1.0000e-21 .
# Iteration = 1900, error = 4.9571e-10 , criteria = 1.0000e-21 .
# Iteration = 2000, error = 1.8802e-10 , criteria = 1.0000e-21 .
# Iteration = 2100, error = 7.1315e-11 , criteria = 1.0000e-21 .
# Iteration = 2200, error = 2.7049e-11 , criteria = 1.0000e-21 .
# Iteration = 2300, error = 1.0260e-11 , criteria = 1.0000e-21 .
# Iteration = 2400, error = 3.8914e-12 , criteria = 1.0000e-21 .
# Iteration = 2500, error = 1.4760e-12 , criteria = 1.0000e-21 .
# Iteration = 2600, error = 5.5983e-13 , criteria = 1.0000e-21 .
# Iteration = 2700, error = 2.1234e-13 , criteria = 1.0000e-21 .
# Iteration = 2800, error = 8.0540e-14 , criteria = 1.0000e-21 .
# Iteration = 2900, error = 3.0548e-14 , criteria = 1.0000e-21 .
# Iteration = 3000, error = 1.1587e-14 , criteria = 1.0000e-21 .
# Iteration = 3100, error = 4.3948e-15 , criteria = 1.0000e-21 .
# Iteration = 3200, error = 1.6669e-15 , criteria = 1.0000e-21 .
# Iteration = 3300, error = 6.3225e-16 , criteria = 1.0000e-21 .
# Iteration = 3400, error = 2.3981e-16 , criteria = 1.0000e-21 .
# Iteration = 3500, error = 9.0959e-17 , criteria = 1.0000e-21 .
# Iteration = 3600, error = 3.4501e-17 , criteria = 1.0000e-21 .
# Iteration = 3700, error = 1.3085e-17 , criteria = 1.0000e-21 .
# Iteration = 3800, error = 4.9636e-18 , criteria = 1.0000e-21 .
# Iteration = 3900, error = 1.8826e-18 , criteria = 1.0000e-21 .
# Iteration = 4000, error = 7.1368e-19 , criteria = 1.0000e-21 .
# Iteration = 4100, error = 2.7164e-19 , criteria = 1.0000e-21 .
# Iteration = 4200, error = 1.0375e-19 , criteria = 1.0000e-21 .
# Iteration = 4300, error = 3.9407e-20 , criteria = 1.0000e-21 .
# Iteration = 4400, error = 1.5633e-20 , criteria = 1.0000e-21 .
# Iteration = 4500, error = 6.4587e-21 , criteria = 1.0000e-21 .
# Iteration = 4600, error = 3.0172e-21 , criteria = 1.0000e-21 .
# Iteration = 4700, error = 1.7015e-21 , criteria = 1.0000e-21 .
# Iteration = 4800, error = 1.1971e-21 , criteria = 1.0000e-21 .
# Iteration = 4900, error = 1.0419e-21 , criteria = 1.0000e-21 .
# Simulation of SOR scheme ends. Total 7.56 s is spent.
# Error 9.9889e-22 has been reached, total iterations is 4925 .
# Error with analytic solution is 7.03307801e-06 .

# %% [markdown]
# ### Plotting Potential

# %%
fig = plt.figure(figsize=(2*6,6), dpi=300)

ax_1 = fig.add_subplot(1, 2, 1, projection='3d')
surf = ax_1.plot_surface(dx*xx, dx*yy, phi, cmap='jet', edgecolor='none', )
ax_1.set_title('Simulated Potential', fontsize=20, y=1.05)
ax_1.view_init(90,-90)
ax_1.axis('tight')
ax_1.set_xlim([0,L])
ax_1.set_ylim([0,L])
ax_1.set_xticks(np.linspace(0,L,5))
ax_1.set_yticks(np.linspace(0,L,5))
ax_1.set_xticklabels(np.linspace(0,L,5), fontsize=10., va='center')
ax_1.set_yticklabels(np.linspace(0,L,5), fontsize=10., va='center', rotation=90)
ax_1.set_zticks([])
ax_1.set_xlabel('x', labelpad=10, fontsize=16)
ax_1.set_ylabel('y', labelpad=10, fontsize=16)
axins_1 = inset_axes(ax_1,
                    width="5%",  # width = 50% of parent_bbox width
                    height="40%",  # height : 5%
                    loc='upper right',
                    bbox_to_anchor=(0.01, -0.2, 1, 1), #(position_x, position_y, bbox_size_x, bbox_size_y)
                    bbox_transform=ax_1.transAxes)
fig.colorbar(surf, shrink=0.3, aspect=10, cax=axins_1)

ax_2 = fig.add_subplot(1, 2, 2, projection='3d')
surf = ax_2.plot_surface(dx*xx, dx*yy, phi_analytic, cmap='jet', edgecolor='none', )
ax_2.set_title('Analytical Potential', fontsize=20, y=1.05)
ax_2.view_init(90,-90)
ax_2.axis('tight')
ax_2.set_xlim([0,L])
ax_2.set_ylim([0,L])
ax_2.set_xticks(np.linspace(0,L,5))
ax_2.set_yticks(np.linspace(0,L,5))
ax_2.set_xticklabels(np.linspace(0,L,5), fontsize=10., va='center')
ax_2.set_yticklabels(np.linspace(0,L,5), fontsize=10., va='center', rotation=90)
ax_2.set_zticks([])
ax_2.set_xlabel('x', labelpad=10, fontsize=16.)
ax_2.set_ylabel('y', labelpad=10, fontsize=16.)
axins_2 = inset_axes(ax_2,
                    width="5%",  # width = 50% of parent_bbox width
                    height="40%",  # height : 5%
                    loc='upper right',
                    bbox_to_anchor=(0.01, -0.2, 1, 1), #(position_x, position_y, bbox_size_x, bbox_size_y)
                    bbox_transform=ax_2.transAxes)
fig.colorbar(surf, shrink=0.3, aspect=10, cax=axins_2)
# plt.savefig("/home/lab/Guan_Ming/Computational_Astrophysics/Homework/HW3/Problem_1_Simulated_v.s._Analytic_Potential_N=256_criteria=1.00000000e-21.png", bbox_inches='tight', dpi=200, pad_inches=0.05)
plt.show()

# %% [markdown]
# ### Plotting Difference

# %%
difference = phi-phi_analytic
ticks=np.linspace(difference.min(), difference.max(),5)

fig = plt.figure(figsize=(3,3), dpi=200)
ax = plt.imshow(difference[::-1,:], cmap='jet') #flip the phi to consistent with the figures above
plt.title("Difference with Analytic Potential", y=1.05)
plt.xlabel('x')
plt.ylabel('y')
plt.xticks(np.linspace(0,N,5), np.linspace(0,L,5))
plt.yticks(np.linspace(0,N,5), np.flip(np.linspace(0,L,5))) # flip the y axis

fig.colorbar(ax, shrink=0.5, aspect=10, ticks=ticks, format='%.2e')
# plt.savefig("/home/lab/Guan_Ming/Computational_Astrophysics/Homework/HW3/Problem_1_Simulated_v.s._Analytic_Potential_Difference_N=256_criteria=1.00000000e-21.png", bbox_inches='tight', dpi=200, pad_inches=0.05)
plt.show()

# %% [markdown]
# ### Optimal $\omega$ Test

# %%
L = 1.0
iteration_max = 1000000
criteria = 1.e-21
N_range = np.array([16, 32, 64])
# show_error_interval = 10000

try: 
    os.makedirs('./Optimal_Omega_Test_Fixed_Boundary_L=1')
except:
    print("Folder already existed!")
path = './Optimal_Omega_Test_Fixed_Boundary_L=1/'

for N in N_range:
    k = 2.0*np.pi/N
    x = np.arange(0,N)
    y = np.arange(0,N)
    xx,yy= np.meshgrid(x,y)

    phi_analytic = np.exp(-k*xx)*np.sin(k*yy)

    rho = np.zeros(N*N)
    boundary = ((yy%N==0) | (yy%N==N-1) | (xx%N==0) | (xx%N==N-1)).ravel()
    
    dx = L/(N-1)
    
#     omega_range = np.arange(0.25, 2.00, 0.01)
    omega_range = np.arange(1.935, 1.9405, 0.0005)

    neighbor_r = np.arange(N*N)
    neighbor_l = np.arange(N*N)
    neighbor_u = np.arange(N*N)
    neighbor_d = np.arange(N*N)
    neighbor_r = N*(neighbor_r//N) + (neighbor_r%N+1)%N
    neighbor_l = N*(neighbor_l//N) + (neighbor_l%N+N-1)%N
    neighbor_u = N*((neighbor_u//N+1)%N) + neighbor_u%N
    neighbor_d = N*((neighbor_d//N+N-1)%N) + neighbor_d%N

    idx_even, idx_odd = CHECKER_BOARD(N)

    iteration_record = []
    total_time_record = []
    error_record = []

    print("Test the optimal omega for SOR scheme with N=%d ."%N)
    for omega in omega_range:
        ### reinitialize the field and parameters
        phi = np.zeros(N*N)
        phi[boundary] = phi_analytic.ravel()[boundary]
        iteration = 0
        error = CALCULATE_CRITERIA(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)
        ###

        start = time.time()
        while error>criteria and iteration<iteration_max: 
            phi = LAPLACIAN_SUCCESSIVE_OVER_RELAXATION(phi, omega, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d, idx_even, idx_odd)
            error = CALCULATE_CRITERIA(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)
            iteration += 1
#             if iteration%show_error_interval == 0:
#                 print("\tIteration = %d, error = %.4e ."%(iteration, error))
        end = time.time()
        print("\tSimulation of omega = %.4e ends. Total %.2f s is spent."%(omega, end-start))
        print("\tError %.4e has been reached, total iterations is %d ."%(error, iteration))
        iteration_record.append(iteration)
        total_time_record.append(end-start)
        error_record.append(error)
        
    error_record = np.array(error_record)
    iteration_record = np.array(iteration_record)
    total_time_record = np.array(total_time_record)

#     data = np.vstack((omega_range, iteration_record,error_record, total_time_record)).T
#     np.savetxt('%sN=%d_criteria=%.8e_optimal_omega_record.txt'%(path, N, criteria), data, fmt="%.8e",\
#                header='Omega\tIteration(s)\tError\tTotal_Time (s)',\
#                footer='Stopping Criteria: %.8e'%criteria)
# Out:
# Folder already existed!
# Test the optimal omega for SOR scheme with N=16 .
# 	Simulation of omega = 1.9350e+00 ends. Total 0.02 s is spent.
# 	Error 7.1687e-22 has been reached, total iterations is 425 .
# 	Simulation of omega = 1.9355e+00 ends. Total 0.02 s is spent.
# 	Error 7.6699e-22 has been reached, total iterations is 428 .
# 	Simulation of omega = 1.9360e+00 ends. Total 0.02 s is spent.
# 	Error 9.4372e-22 has been reached, total iterations is 430 .
# 	Simulation of omega = 1.9365e+00 ends. Total 0.02 s is spent.
# 	Error 9.7084e-22 has been reached, total iterations is 434 .
# 	Simulation of omega = 1.9370e+00 ends. Total 0.02 s is spent.
# 	Error 5.1066e-22 has been reached, total iterations is 440 .
# 	Simulation of omega = 1.9375e+00 ends. Total 0.02 s is spent.
# 	Error 8.1940e-22 has been reached, total iterations is 440 .
# 	Simulation of omega = 1.9380e+00 ends. Total 0.02 s is spent.
# 	Error 9.0576e-22 has been reached, total iterations is 444 .
# 	Simulation of omega = 1.9385e+00 ends. Total 0.02 s is spent.
# 	Error 9.1855e-22 has been reached, total iterations is 449 .
# 	Simulation of omega = 1.9390e+00 ends. Total 0.02 s is spent.
# 	Error 8.7393e-22 has been reached, total iterations is 452 .
# 	Simulation of omega = 1.9395e+00 ends. Total 0.02 s is spent.
# 	Error 7.2753e-22 has been reached, total iterations is 458 .
# 	Simulation of omega = 1.9400e+00 ends. Total 0.02 s is spent.
# 	Error 9.6115e-22 has been reached, total iterations is 461 .
# Test the optimal omega for SOR scheme with N=32 .
# 	Simulation of omega = 1.9350e+00 ends. Total 0.03 s is spent.
# 	Error 8.4659e-22 has been reached, total iterations is 441 .
# 	Simulation of omega = 1.9355e+00 ends. Total 0.03 s is spent.
# 	Error 9.6068e-22 has been reached, total iterations is 446 .
# 	Simulation of omega = 1.9360e+00 ends. Total 0.03 s is spent.
# 	Error 9.2506e-22 has been reached, total iterations is 447 .
# 	Simulation of omega = 1.9365e+00 ends. Total 0.03 s is spent.
# 	Error 9.6364e-22 has been reached, total iterations is 450 .
# 	Simulation of omega = 1.9370e+00 ends. Total 0.03 s is spent.
# 	Error 8.4808e-22 has been reached, total iterations is 455 .
# 	Simulation of omega = 1.9375e+00 ends. Total 0.03 s is spent.
# 	Error 8.0797e-22 has been reached, total iterations is 459 .
# 	Simulation of omega = 1.9380e+00 ends. Total 0.03 s is spent.
# 	Error 9.0449e-22 has been reached, total iterations is 463 .
# 	Simulation of omega = 1.9385e+00 ends. Total 0.03 s is spent.
# 	Error 9.8401e-22 has been reached, total iterations is 467 .
# 	Simulation of omega = 1.9390e+00 ends. Total 0.03 s is spent.
# 	Error 7.8212e-22 has been reached, total iterations is 471 .
# 	Simulation of omega = 1.9395e+00 ends. Total 0.03 s is spent.
# 	Error 8.9285e-22 has been reached, total iterations is 476 .
# 	Simulation of omega = 1.9400e+00 ends. Total 0.03 s is spent.
# 	Error 9.0572e-22 has been reached, total iterations is 478 .
# Test the optimal omega for SOR scheme with N=64 .
# 	Simulation of omega = 1.9350e+00 ends. Total 0.06 s is spent.
# 	Error 7.8088e-22 has been reached, total iterations is 458 .
# 	Simulation of omega = 1.9355e+00 ends. Total 0.06 s is spent.
# 	Error 7.2409e-22 has been reached, total iterations is 462 .
# 	Simulation of omega = 1.9360e+00 ends. Total 0.06 s is spent.
# 	Error 9.1506e-22 has been reached, total iterations is 463 .
# 	Simulation of omega = 1.9365e+00 ends. Total 0.06 s is spent.
# 	Error 9.6977e-22 has been reached, total iterations is 468 .
# 	Simulation of omega = 1.9370e+00 ends. Total 0.06 s is spent.
# 	Error 9.9931e-22 has been reached, total iterations is 471 .
# 	Simulation of omega = 1.9375e+00 ends. Total 0.06 s is spent.
# 	Error 9.2020e-22 has been reached, total iterations is 476 .
# 	Simulation of omega = 1.9380e+00 ends. Total 0.06 s is spent.
# 	Error 8.4604e-22 has been reached, total iterations is 481 .
# 	Simulation of omega = 1.9385e+00 ends. Total 0.06 s is spent.
# 	Error 8.3045e-22 has been reached, total iterations is 485 .
# 	Simulation of omega = 1.9390e+00 ends. Total 0.06 s is spent.
# 	Error 8.6289e-22 has been reached, total iterations is 489 .
# 	Simulation of omega = 1.9395e+00 ends. Total 0.06 s is spent.
# 	Error 8.9664e-22 has been reached, total iterations is 493 .
# 	Simulation of omega = 1.9400e+00 ends. Total 0.06 s is spent.
# 	Error 8.4405e-22 has been reached, total iterations is 497 .

# %% [markdown]
# ### Plotting out the result

# %%
N_list = []
data_list = []
path = './Optimal_Omega_Test_Fixed_Boundary_L=1/'
files = os.listdir(path)

for file in files:
    if '.txt' in file and '1.00000000e-21' in file:
        data = np.loadtxt('%s%s'%(path, file))
        omega_range, iteration_record, error_record, total_time_record = data[:,0], data[:,1], data[:,2], data[:,3]
        criteria = eval(file.split('_')[1].split('=')[-1])
        lattice_size = eval(file.split('_')[0].split('=')[-1])
        data = np.vstack((omega_range[error_record<criteria], iteration_record[error_record<criteria], \
                          total_time_record[error_record<criteria])).T
        N_list.append(lattice_size)
        data_list.append(data)
dict_data = dict(zip(N_list, data_list))

fig = plt.figure(figsize=(2*3,3), dpi=200)
plt.subplots_adjust(wspace=0.4)
ax_1 = plt.subplot(121)
ax_2 = plt.subplot(122)
for N in sorted(list(dict_data.keys())):
    data = dict_data[N]
    ax_1.semilogy(data[:,0], data[:,1], lw=0.0, marker='o', markersize=2.0, label='N=%d'%N)
    ax_2.semilogy(data[:,0], data[:,2], lw=0.0, marker='o', markersize=2.0, label='N=%d'%N)
    print(N, data[:,0][np.argmin(data[:,1])], data[:,1].min())
    
ax_1.set_xlabel('$\omega$', fontsize=8.)
ax_1.set_ylabel('# of Iterations for Convergence')
ax_1.set_title('# of Iterations v.s $\omega$',y=1.03)
ax_1.set_xticks(np.arange(0.0,2.5,0.5))
ax_1.set_xlim([0.25,2.0])
ax_1.legend(loc='upper right', prop={'size':5.0})
ax_2.set_xlabel('$\omega$', fontsize=8.)
ax_2.set_ylabel('Total Simulation Time (s)')
ax_2.set_title('Total Simuation Time v.s $\omega$',y=1.03)
ax_2.set_xticks(np.arange(0.0,2.5,0.5))
ax_2.set_xlim([0.25,2.0])
ax_2.legend(loc='upper right', prop={'size':5.0})
plt.savefig("/home/lab/Guan_Ming/Computational_Astrophysics/Homework/HW3/Problem_2_Optimal_omega_Fixed_Boundary.png", bbox_inches='tight', dpi=200, pad_inches=0.05)
plt.show()
# Out:
# 16 1.66 69.0
# 32 1.82 150.0
# 64 1.91 326.0
# 128 1.95 661.0

# %%
fig = plt.figure(figsize=(2*3,3), dpi=200)
plt.subplots_adjust(wspace=0.4)
ax_1 = plt.subplot(121)
ax_2 = plt.subplot(122)

reference_omega = dict_data[16][:,0]>=0.25
reference_iteration = dict_data[16][reference_omega,1]
reference_time = dict_data[16][reference_omega,2]

for N in [16, 32, 64, 128]:
    data = dict_data[N]
    omega_range = data[:,0]>=0.25
    ax_1.plot(data[omega_range,0], np.log2(data[omega_range,1]/reference_iteration),\
              lw=0.0, marker='o', markersize=2.0, label='N=%d'%N)
    ax_2.plot(data[omega_range,0], np.log2(data[omega_range,2]/reference_time),\
              lw=0.0, marker='o', markersize=2.0, label='N=%d'%N)
    
ax_1.set_xlabel('$\omega$', fontsize=8.)
ax_1.set_ylabel('$log_2$ Iterations')
ax_1.set_title('$log_2$ Iterations v.s $\omega$\n($N=16$ as reference)',y=1.03)
ax_1.set_xticks(np.arange(0.5,2.5,0.5))
ax_1.set_xlim([0.25,2.0])
ax_1.set_ylim([-0.5,8.2])
ax_1.legend(loc='upper right', prop={'size':5.0})
ax_2.set_xlabel('$\omega$', fontsize=8.)
ax_2.set_ylabel('$log_2$ Simulation Time')
ax_2.set_title('$log_2$ Simuation Time v.s $\omega$\n($N=16$ as reference)',y=1.03)
ax_2.set_xticks(np.arange(0.0,2.0,0.5))
ax_2.set_yticks(np.arange(0.0,11,1.0))
ax_2.set_xlim([0.25,2.0])
ax_2.set_ylim([-0.5,10.])
ax_2.legend(loc='upper right', prop={'size':5.0})
plt.show()

# %% [markdown]
# ### Fitting optimal $\omega$

# %%
N_range = np.array([16,32,64,128])
optimal_omega = np.array([1.66, 1.82, 1.91, 1.95])
x_range = np.linspace(1,128,500)

plt.figure(figsize=(2,2), dpi=200)
plt.scatter(N_range, optimal_omega, s=5.0, c='blue')
plt.plot(x_range, 4./(2.+(4.-4.*np.cos(np.pi/x_range)**2)**0.5), color='red', lw=1.0, ls='--')
plt.xlabel("$N$", fontsize=8.0)
plt.ylabel("Optimal $\omega$", fontsize=8.0)
plt.xlim(0,130)
plt.ylim(1.0,2.0)
plt.xticks([16,32,64,128],fontsize=8.0)
plt.yticks(fontsize=8.0)
plt.savefig("/home/lab/Guan_Ming/Computational_Astrophysics/Homework/HW3/Problem_2_Optimal_omega_v.s._N_Fixed_Boundary.png", bbox_inches='tight', dpi=200, pad_inches=0.05)

# %% [markdown]
# ### Lattice Size v.s. Error, Iterations, Total Time

# %%
L = 1.0
N_range = np.array([16, 32, 64, 128, 256])
optimal_omega = np.array([1.66, 1.82, 1.91, 1.95, 1.93755])

# for mode in ['jacobi','gauss_seidel','SOR']:
for mode in ['jacobi','gauss_seidel','SOR']:
    error_analytic_record = []
    total_time_record = []
    iteration_record = []
    for i, N in enumerate(N_range):
        k = 2.0*np.pi/N
        x = np.arange(0,N)
        y = np.arange(0,N)
        xx,yy= np.meshgrid(x,y)

        phi_analytic = np.exp(-k*xx)*np.sin(k*yy)

        phi = np.zeros(N*N)
        rho = np.zeros(N*N)
        boundary = ((yy%N==0) | (yy%N==N-1) | (xx%N==0) | (xx%N==N-1)).ravel()
        phi[boundary] = phi_analytic.ravel()[boundary]
        iteration = 0
        iteration_max = 4000000
        dx = L/(N-1)
        show_error_interval = 100

        neighbor_r = np.arange(N*N)
        neighbor_l = np.arange(N*N)
        neighbor_u = np.arange(N*N)
        neighbor_d = np.arange(N*N)
        neighbor_r = N*(neighbor_r//N) + (neighbor_r%N+1)%N
        neighbor_l = N*(neighbor_l//N) + (neighbor_l%N+N-1)%N
        neighbor_u = N*((neighbor_u//N+1)%N) + neighbor_u%N
        neighbor_d = N*((neighbor_d//N+N-1)%N) + neighbor_d%N

        # criteria = CALCULATE_CRITERIA(phi_analytic.ravel(), rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)
        criteria = 1e-21
        error = CALCULATE_CRITERIA(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)
        print("Lattice size = %d using %s scheme:"%(N, mode))
        if mode=='jacobi':
            phi_copy = phi.copy()
            flag = True
            #     idx_boundary = boundary==False
            idx_not_boundary = np.argwhere(boundary==False).reshape(-1)
        elif mode=='gauss_seidel' or mode=='SOR':
            idx_even, idx_odd = CHECKER_BOARD(N)
            if mode == 'SOR':
                omega = optimal_omega[i]
        start = time.time()
        while error>criteria and iteration<iteration_max:
            if mode=='jacobi':
                if flag:
                    phi_copy[boundary==False] = LAPLACIAN_JACOBI(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d, idx_not_boundary)
                    error = CALCULATE_CRITERIA(phi_copy, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)
                else:
                    phi[boundary==False] = LAPLACIAN_JACOBI(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d, idx_not_boundary)
                    error = CALCULATE_CRITERIA(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)
                flag = not flag
            elif mode=='gauss_seidel':
                phi = LAPLACIAN_GAUSS_SEIDEL(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d, idx_even, idx_odd)
                error = CALCULATE_CRITERIA(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)
            else:
                phi = LAPLACIAN_SUCCESSIVE_OVER_RELAXATION(phi, omega, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d, idx_even, idx_odd)
                error = CALCULATE_CRITERIA(phi, rho, neighbor_r, neighbor_l, neighbor_u, neighbor_d)
            iteration += 1
    #         if iteration%show_error_interval == 0:
    #             print("Iteration = %d, error = %.4e , criteria = %.4e ."%(iteration, error, criteria))
        if mode=='jacobi':
            if flag:
                phi = phi.copy()
        end = time.time()
        iteration_record.append(iteration)
        error_analytic_record.append((((phi-phi_analytic.ravel())**2).mean())**0.5)
        total_time_record.append(end-start)
        print("\tSimulation of %s scheme ends. Total %.2f s is spent."%(mode, end-start))
        print("\tError %.4e has been reached, total iterations is %d ."%(error, iteration))
        print("\tError with analytic solution is %.8e ."%error_analytic_record[-1])

    data = np.vstack((np.array(N_range),np.array(iteration_record), np.array(error_analytic_record), \
                      np.array(total_time_record))).T
#     with open('Error_vs_Lattice_Size_%s_Criteria=%.8e.txt'%(mode,criteria), 'w') as f:
#         np.savetxt(f, data, fmt="%.8e",\
#                    header='Lattice Size\tIteration(s)\tError\tTotal_Time (s)',\
#                    footer='Stopping Criteria: %.8e'%criteria)
# Out:
# Lattice size = 16 using jacobi scheme:
# 	Simulation of jacobi scheme ends. Total 0.06 s is spent.
# 	Error 9.8311e-22 has been reached, total iterations is 2017 .
# 	Error with analytic solution is 1.64406205e-03 .
# Lattice size = 32 using jacobi scheme:
# 	Simulation of jacobi scheme ends. Total 0.37 s is spent.
# 	Error 9.9700e-22 has been reached, total iterations is 8321 .
# 	Error with analytic solution is 4.32943368e-04 .
# Lattice size = 64 using jacobi scheme:
# 	Simulation of jacobi scheme ends. Total 3.35 s is spent.
# 	Error 9.9808e-22 has been reached, total iterations is 33157 .
# 	Error with analytic solution is 1.10761037e-04 .
# Lattice size = 16 using gauss_seidel scheme:
# 	Simulation of gauss_seidel scheme ends. Total 0.02 s is spent.
# 	Error 9.3275e-22 has been reached, total iterations is 513 .
# 	Error with analytic solution is 1.64406205e-03 .
# Lattice size = 32 using gauss_seidel scheme:
# 	Simulation of gauss_seidel scheme ends. Total 0.11 s is spent.
# 	Error 9.8408e-22 has been reached, total iterations is 2115 .
# 	Error with analytic solution is 4.32943368e-04 .
# Lattice size = 64 using gauss_seidel scheme:
# 	Simulation of gauss_seidel scheme ends. Total 0.92 s is spent.
# 	Error 9.9816e-22 has been reached, total iterations is 8429 .
# 	Error with analytic solution is 1.10761037e-04 .
# Lattice size = 16 using SOR scheme:
# 	Simulation of SOR scheme ends. Total 0.00 s is spent.
# 	Error 9.5335e-22 has been reached, total iterations is 69 .
# 	Error with analytic solution is 1.64406205e-03 .
# Lattice size = 32 using SOR scheme:
# 	Simulation of SOR scheme ends. Total 0.01 s is spent.
# 	Error 7.0744e-22 has been reached, total iterations is 150 .
# 	Error with analytic solution is 4.32943369e-04 .
# Lattice size = 64 using SOR scheme:
# 	Simulation of SOR scheme ends. Total 0.04 s is spent.
# 	Error 8.8050e-22 has been reached, total iterations is 326 .
# 	Error with analytic solution is 1.10761037e-04 .

# %%
scheme_list = []
data_list = []
for file in os.listdir('./'):
    if "Error" in file:
        if 'jacobi' in file:
            scheme_list.append('Jacobi')
            data_list.append(np.loadtxt('%s'%file))
        elif 'gauss_seidel' in file:
            scheme_list.append('Gauss-Seidel')
            data_list.append(np.loadtxt('%s'%file))
        elif 'SOR' in file:
            scheme_list.append('SOR')
            data_list.append(np.loadtxt('%s'%file))
dict_data = dict(zip(scheme_list, data_list))

# %%
count = 0
fig = plt.figure(figsize=(3*3,3), dpi=200)
plt.subplots_adjust(wspace=0.6)
ax_1 = plt.subplot(131)
ax_2 = plt.subplot(132)
ax_3 = plt.subplot(133)
for scheme in list(dict_data.keys()):
    data_lattice_size = np.log2(dict_data[scheme][:4,0])
    data_iteration = np.log2(dict_data[scheme][:4,1])
    data_error = np.log2(dict_data[scheme][:4,2])
    data_total_time = np.log2(dict_data[scheme][:4,3])
    
    ax_1.plot(data_lattice_size, data_error, lw=0.0, marker='o', markersize=2.0, label="%s"%scheme)
    if count==0:
        prop, pocp = curve_fit(linear_fit, data_lattice_size, data_error)
        ax_1.plot(data_lattice_size, prop[0]*data_lattice_size+prop[1], lw = 0.5, ls='--', c='red')
        ax_1.text(5.2, -11.5,"slope = %.4f"%prop[0], fontsize=8.0)
    
    prop, pocp = curve_fit(linear_fit, data_lattice_size[:4], data_iteration[:4])
    if scheme == 'SOR':
        ax_2.plot(data_lattice_size, prop[0]*data_lattice_size+prop[1], lw = 0.5, ls='--', c='blue')
    elif scheme == 'Gauss-Seidel':
        ax_2.plot(data_lattice_size, prop[0]*data_lattice_size+prop[1], lw = 0.5, ls='--', c='lime')
    else:
        ax_2.plot(data_lattice_size, prop[0]*data_lattice_size+prop[1], lw = 0.5, ls='--', c='gold')
    ax_2.plot(data_lattice_size, data_iteration, lw=0.0, marker='o', markersize=2.0, label="%s Slope=%.4f"%(scheme,prop[0]))
       
    prop, pocp = curve_fit(linear_fit, data_lattice_size, data_total_time)
    if scheme == 'SOR':
        ax_3.plot(data_lattice_size, prop[0]*data_lattice_size+prop[1], lw = 0.5, ls='--', c='blue')
    elif scheme == 'Gauss-Seidel':
        ax_3.plot(data_lattice_size, prop[0]*data_lattice_size+prop[1], lw = 0.5, ls='--', c='lime')
    else:
        ax_3.plot(data_lattice_size, prop[0]*data_lattice_size+prop[1], lw = 0.5, ls='--', c='gold')
    ax_3.plot(data_lattice_size, data_total_time, lw=0.0, marker='o', markersize=2.0, label="%s Slope=%.4f"%(scheme, prop[0])) 
        
    count += 1
ax_1.set_xlabel('$log_2N$', fontsize=12.)
ax_1.set_ylabel('$log_2$Error', fontsize=12.)
ax_1.set_title('$log_2-log_2$ Error v.s. $N$',y=1.03)
ax_1.legend(loc='upper right', prop={'size':5.0})
ax_2.set_xlabel('$log_2N$', fontsize=12.)
ax_2.set_ylabel('$log_2$ Iterations', fontsize=12.)
ax_2.set_title('$log_2-log_2$ Iterations v.s. $N$',y=1.03)
ax_2.legend(loc='upper left', prop={'size':5.0})
ax_3.set_xlabel('$log_2N$', fontsize=12.)
ax_3.set_ylabel('$log_2$ Clock-Time', fontsize=12.)
ax_3.set_title('$log_2-log_2$ Clock-Time v.s. $N$',y=1.03)
ax_3.legend(loc='upper left', prop={'size':5.0})
plt.savefig("/home/lab/Guan_Ming/Computational_Astrophysics/Homework/HW3/Problem_1_lattice_size_v.s.error_iterations_clock-time.png", bbox_inches='tight', dpi=200, pad_inches=0.05)
